# %%
# import liberary
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# read dataset
df=pd.read_csv(r"C:\Users\Pankaj\Downloads\\Micro-credit-Data-file (1).csv")
# print the top head
df.head()
# Out:
#    Unnamed: 0  label       msisdn    aon  daily_decr30  daily_decr90  \
# 0           1      0  21408I70789  272.0   3055.050000   3065.150000
# 1           2      1  76462I70374  712.0  12122.000000  12124.750000
# 2           3      1  17943I70372  535.0   1398.000000   1398.000000
# 3           4      1  55773I70781  241.0     21.228000     21.228000
# 4           5      1  03813I82730  947.0    150.619333    150.619333
#
#    rental30  rental90  last_rech_date_ma  last_rech_date_da  ...  \
# 0    220.13    260.13                2.0                0.0  ...
# 1   3691.26   3691.26               20.0                0.0  ...
# 2    900.13    900.13                3.0                0.0  ...
# 3    159.42    159.42               41.0                0.0  ...
# 4   1098.90   1098.90                4.0                0.0  ...
#
#    maxamnt_loans30  medianamnt_loans30  cnt_loans90  amnt_loans90  \
# 0              6.0                 0.0          2.0            12
# ...

# %%
# print the bottom
df.tail()
# Out:
#         Unnamed: 0  label       msisdn     aon  daily_decr30  daily_decr90  \
# 209588      209589      1  22758I85348   404.0    151.872333    151.872333
# 209589      209590      1  95583I84455  1075.0     36.936000     36.936000
# 209590      209591      1  28556I85350  1013.0  11843.111670  11904.350000
# 209591      209592      1  59712I82733  1732.0  12488.228330  12574.370000
# 209592      209593      1  65061I85339  1581.0   4489.362000   4534.820000
#
#         rental30  rental90  last_rech_date_ma  last_rech_date_da  ...  \
# 209588   1089.19   1089.19                1.0                0.0  ...
# 209589   1728.36   1728.36                4.0                0.0  ...
# 209590   5861.83   8893.20                3.0                0.0  ...
# 209591    411.83    984.58                2.0               38.0  ...
# 209592    483.92    631.20               13.0                0.0  ...
#
#         maxamnt_loans30  medianamnt_loans30  cnt_loans90  amnt_loans90  \
# ...

# %%
# print maximum rows and columns from the dataset
pd.set_option("display.max_columns",None)
pd.set_option("display.max_rows",None)

# %%
# print the  all columns in dataset
df.columns
# Out:
# Index(['Unnamed: 0', 'label', 'msisdn', 'aon', 'daily_decr30', 'daily_decr90',
#        'rental30', 'rental90', 'last_rech_date_ma', 'last_rech_date_da',
#        'last_rech_amt_ma', 'cnt_ma_rech30', 'fr_ma_rech30',
#        'sumamnt_ma_rech30', 'medianamnt_ma_rech30', 'medianmarechprebal30',
#        'cnt_ma_rech90', 'fr_ma_rech90', 'sumamnt_ma_rech90',
#        'medianamnt_ma_rech90', 'medianmarechprebal90', 'cnt_da_rech30',
#        'fr_da_rech30', 'cnt_da_rech90', 'fr_da_rech90', 'cnt_loans30',
#        'amnt_loans30', 'maxamnt_loans30', 'medianamnt_loans30', 'cnt_loans90',
#        'amnt_loans90', 'maxamnt_loans90', 'medianamnt_loans90', 'payback30',
#        'payback90', 'pcircle', 'pdate'],
#       dtype='object')

# %%
# check the shape of dataset
df.shape
# Out:
# (209593, 37)

# %%
#check the null value
df.isnull().sum()
# Out:
# Unnamed: 0              0
# label                   0
# msisdn                  0
# aon                     0
# daily_decr30            0
# daily_decr90            0
# rental30                0
# rental90                0
# last_rech_date_ma       0
# last_rech_date_da       0
# last_rech_amt_ma        0
# cnt_ma_rech30           0
# fr_ma_rech30            0
# sumamnt_ma_rech30       0
# medianamnt_ma_rech30    0
# medianmarechprebal30    0
# cnt_ma_rech90           0
# fr_ma_rech90            0
# sumamnt_ma_rech90       0
# medianamnt_ma_rech90    0
# medianmarechprebal90    0
# cnt_da_rech30           0
# fr_da_rech30            0
# cnt_da_rech90           0
# fr_da_rech90            0
# cnt_loans30             0
# amnt_loans30            0
# maxamnt_loans30         0
# medianamnt_loans30      0
# cnt_loans90             0
# amnt_loans90            0
# maxamnt_loans90         0
# medianamnt_loans90      0
# payback30               0
# payback90               0
# ...

# %%
# check the total null value
df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# # No Null value in Dataset

# %%
# check the information in dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209593 entries, 0 to 209592
# Data columns (total 37 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Unnamed: 0            209593 non-null  int64
#  1   label                 209593 non-null  int64
#  2   msisdn                209593 non-null  object
#  3   aon                   209593 non-null  float64
#  4   daily_decr30          209593 non-null  float64
#  5   daily_decr90          209593 non-null  float64
#  6   rental30              209593 non-null  float64
#  7   rental90              209593 non-null  float64
#  8   last_rech_date_ma     209593 non-null  float64
#  9   last_rech_date_da     209593 non-null  float64
#  10  last_rech_amt_ma      209593 non-null  int64
#  11  cnt_ma_rech30         209593 non-null  int64
#  12  fr_ma_rech30          209593 non-null  float64
#  13  sumamnt_ma_rech30     209593 non-null  float64
# ...

# %%
# drop unnamed column from the dataset
df=df.drop(columns=["Unnamed: 0"],axis=1)

# %%
# print the head
df.head()
# Out:
#    label       msisdn    aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0      0  21408I70789  272.0   3055.050000   3065.150000    220.13    260.13
# 1      1  76462I70374  712.0  12122.000000  12124.750000   3691.26   3691.26
# 2      1  17943I70372  535.0   1398.000000   1398.000000    900.13    900.13
# 3      1  55773I70781  241.0     21.228000     21.228000    159.42    159.42
# 4      1  03813I82730  947.0    150.619333    150.619333   1098.90   1098.90
#
#    last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  \
# 0                2.0                0.0              1539              2
# 1               20.0                0.0              5787              1
# 2                3.0                0.0              1539              1
# 3               41.0                0.0               947              0
# 4                4.0                0.0              2309              7
#
#    fr_ma_rech30  sumamnt_ma_rech30  medianamnt_ma_rech30  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209593 entries, 0 to 209592
# Data columns (total 36 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   label                 209593 non-null  int64
#  1   msisdn                209593 non-null  object
#  2   aon                   209593 non-null  float64
#  3   daily_decr30          209593 non-null  float64
#  4   daily_decr90          209593 non-null  float64
#  5   rental30              209593 non-null  float64
#  6   rental90              209593 non-null  float64
#  7   last_rech_date_ma     209593 non-null  float64
#  8   last_rech_date_da     209593 non-null  float64
#  9   last_rech_amt_ma      209593 non-null  int64
#  10  cnt_ma_rech30         209593 non-null  int64
#  11  fr_ma_rech30          209593 non-null  float64
#  12  sumamnt_ma_rech30     209593 non-null  float64
#  13  medianamnt_ma_rech30  209593 non-null  float64
# ...

# %%
# ccheck the description of dataset
df.describe()
# Out:
#                label            aon   daily_decr30   daily_decr90  \
# count  209593.000000  209593.000000  209593.000000  209593.000000
# mean        0.875177    8112.343445    5381.402289    6082.515068
# std         0.330519   75696.082531    9220.623400   10918.812767
# min         0.000000     -48.000000     -93.012667     -93.012667
# 25%         1.000000     246.000000      42.440000      42.692000
# 50%         1.000000     527.000000    1469.175667    1500.000000
# 75%         1.000000     982.000000    7244.000000    7802.790000
# max         1.000000  999860.755200  265926.000000  320630.000000
#
#             rental30       rental90  last_rech_date_ma  last_rech_date_da  \
# count  209593.000000  209593.000000       209593.00000      209593.000000
# mean     2692.581910    3483.406534         3755.84780        3712.202921
# std      4308.586781    5770.461279        53905.89223       53374.833430
# min    -23737.140000  -24720.580000          -29.00000         -29.000000
# ...

# %% [markdown]
# # LABELE ENCODING

# %%
# Extract numeric part and convert to float
df["msisdn"] = df["msisdn"].str.extract('(\d+)').astype(float)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\Pankaj\AppData\Local\Temp\ipykernel_18200\251465545.py:2: SyntaxWarning: invalid escape sequence '\d'
#   df["msisdn"] = df["msisdn"].str.extract('(\d+)').astype(float)

# %%
# import the labelincoder
from sklearn.preprocessing import LabelEncoder
la=LabelEncoder()

# %%
#  categrical features
df["pcircle"]=la.fit_transform(df["pcircle"])
df.head()
# Out:
#    label   msisdn    aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0      0  21408.0  272.0   3055.050000   3065.150000    220.13    260.13
# 1      1  76462.0  712.0  12122.000000  12124.750000   3691.26   3691.26
# 2      1  17943.0  535.0   1398.000000   1398.000000    900.13    900.13
# 3      1  55773.0  241.0     21.228000     21.228000    159.42    159.42
# 4      1   3813.0  947.0    150.619333    150.619333   1098.90   1098.90
#
#    last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  \
# 0                2.0                0.0              1539              2
# 1               20.0                0.0              5787              1
# 2                3.0                0.0              1539              1
# 3               41.0                0.0               947              0
# 4                4.0                0.0              2309              7
#
#    fr_ma_rech30  sumamnt_ma_rech30  medianamnt_ma_rech30  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209593 entries, 0 to 209592
# Data columns (total 36 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   label                 209593 non-null  int64
#  1   msisdn                209593 non-null  float64
#  2   aon                   209593 non-null  float64
#  3   daily_decr30          209593 non-null  float64
#  4   daily_decr90          209593 non-null  float64
#  5   rental30              209593 non-null  float64
#  6   rental90              209593 non-null  float64
#  7   last_rech_date_ma     209593 non-null  float64
#  8   last_rech_date_da     209593 non-null  float64
#  9   last_rech_amt_ma      209593 non-null  int64
#  10  cnt_ma_rech30         209593 non-null  int64
#  11  fr_ma_rech30          209593 non-null  float64
#  12  sumamnt_ma_rech30     209593 non-null  float64
#  13  medianamnt_ma_rech30  209593 non-null  float64
# ...

# %%
# check the discription of dataset
df.describe()
# Out:
#                label         msisdn            aon   daily_decr30  \
# count  209593.000000  209593.000000  209593.000000  209593.000000
# mean        0.875177   49748.715930    8112.343445    5381.402289
# std         0.330519   28905.713576   75696.082531    9220.623400
# min         0.000000       4.000000     -48.000000     -93.012667
# 25%         1.000000   24659.000000     246.000000      42.440000
# 50%         1.000000   49056.000000     527.000000    1469.175667
# 75%         1.000000   75033.000000     982.000000    7244.000000
# max         1.000000   99998.000000  999860.755200  265926.000000
#
#         daily_decr90       rental30       rental90  last_rech_date_ma  \
# count  209593.000000  209593.000000  209593.000000       209593.00000
# mean     6082.515068    2692.581910    3483.406534         3755.84780
# std     10918.812767    4308.586781    5770.461279        53905.89223
# min       -93.012667  -23737.140000  -24720.580000          -29.00000
# ...

# %% [markdown]
# # EDA(EXPLORATRY DATA ANALYSIS)

# %%
# print the dataset
df.columns
# Out:
# Index(['label', 'msisdn', 'aon', 'daily_decr30', 'daily_decr90', 'rental30',
#        'rental90', 'last_rech_date_ma', 'last_rech_date_da',
#        'last_rech_amt_ma', 'cnt_ma_rech30', 'fr_ma_rech30',
#        'sumamnt_ma_rech30', 'medianamnt_ma_rech30', 'medianmarechprebal30',
#        'cnt_ma_rech90', 'fr_ma_rech90', 'sumamnt_ma_rech90',
#        'medianamnt_ma_rech90', 'medianmarechprebal90', 'cnt_da_rech30',
#        'fr_da_rech30', 'cnt_da_rech90', 'fr_da_rech90', 'cnt_loans30',
#        'amnt_loans30', 'maxamnt_loans30', 'medianamnt_loans30', 'cnt_loans90',
#        'amnt_loans90', 'maxamnt_loans90', 'medianamnt_loans90', 'payback30',
#        'payback90', 'pcircle', 'pdate'],
#       dtype='object')

# %%
# drop date column
df=df.drop(columns=["pdate"],axis=1)

# %%
# check the shape of dataset
df.shape
# Out:
# (209593, 35)

# %%
df.head()
# Out:
#    label   msisdn    aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0      0  21408.0  272.0   3055.050000   3065.150000    220.13    260.13
# 1      1  76462.0  712.0  12122.000000  12124.750000   3691.26   3691.26
# 2      1  17943.0  535.0   1398.000000   1398.000000    900.13    900.13
# 3      1  55773.0  241.0     21.228000     21.228000    159.42    159.42
# 4      1   3813.0  947.0    150.619333    150.619333   1098.90   1098.90
#
#    last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  \
# 0                2.0                0.0              1539              2
# 1               20.0                0.0              5787              1
# 2                3.0                0.0              1539              1
# 3               41.0                0.0               947              0
# 4                4.0                0.0              2309              7
#
#    fr_ma_rech30  sumamnt_ma_rech30  medianamnt_ma_rech30  \
# ...

# %%
# worning ignore
import warnings
warnings.filterwarnings("ignore")

# %%
# distribution plot
plt.figure(figsize=(20,20))
graph=1
for num in df[:35]:
    plt.subplot(6,6,graph)
    sns.distplot(df[num])
    plt.xlabel(num,fontsize=12)
    graph+=1
plt.show()
# check the univarient

# %%
# drop pcircle column
df=df.drop(columns=["pcircle"],axis=1)

# %%
# after the check of distribution
plt.figure(figsize=(20,20))
graph=1
for num in df[:35]:
    plt.subplot(6,6,graph)
    sns.distplot(df[num])
    plt.xlabel(num,fontsize=12)
    graph+=1
plt.show()

# %%
#check the shape
df.shape
# Out:
# (209593, 34)

# %%
# print the heatmap and chek the multicolinearity
plt.figure(figsize=(60,60))

sns.heatmap(abs(df.corr()),annot=True) # check the correelation
# Out:
# <Axes: >

# %% [markdown]
# # IT IS HIGHLY MULTICOLINEARITY SO MANY COLUMNS

# %%
df.corr()
# Out:
#                          label    msisdn       aon  daily_decr30  \
# label                 1.000000  0.001945 -0.003785      0.168298
# msisdn                0.001945  1.000000  0.000555      0.000669
# aon                  -0.003785  0.000555  1.000000      0.001104
# daily_decr30          0.168298  0.000669  0.001104      1.000000
# daily_decr90          0.166150  0.000903  0.000374      0.977704
# rental30              0.058085 -0.001437 -0.000960      0.442066
# rental90              0.075521 -0.000728 -0.000790      0.458977
# last_rech_date_ma     0.003728 -0.000949  0.001692      0.000487
# last_rech_date_da     0.001711  0.001404 -0.001693     -0.001636
# last_rech_amt_ma      0.131804 -0.002356  0.004256      0.275837
# cnt_ma_rech30         0.237331  0.000585 -0.003148      0.451385
# fr_ma_rech30          0.001330 -0.001812 -0.001163     -0.000577
# sumamnt_ma_rech30     0.202828  0.001074  0.000707      0.636536
# ...

# %%
# check the shape
df.shape
# Out:
# (209593, 34)

# %%
df.drop("label",axis=1).corrwith(df["label"]).plot(kind="bar",grid=True,title="corr with label",figsize=(20,20)) # corr with label
# Out:
# <Axes: title={'center': 'corr with label'}>

# %% [markdown]
# # check the outlier

# %%
plt.figure(figsize=(40,40))
graph=1
for num in df[:34]:
    plt.subplot(6,6,graph)
    sns.boxplot(data=df[num],orient="v")
    plt.xlabel(num,fontsize=12)
    graph+=1
plt.show()

# %% [markdown]
# #  remoove outlier some importent feature (it is highly skewed dataframe)

# %%
df.shape
# Out:
# (209593, 34)

# %%
from scipy.stats.mstats import winsorize

#  Filter rows within 2nd and 98th percentiles
lower_bound = df["aon"].quantile(0.02)
upper_bound = df["aon"].quantile(0.98)

# remoove the outlier in aon
df = df[(df["aon"] >= lower_bound) & (df["aon"] <= upper_bound)]

# Cap extreme values (Winsorization) on remaining data
df["aon"] = winsorize(df["aon"], limits=[0.01, 0.01])  # Cap at 1% from each side

df = df.reset_index(drop=True)
print(df.shape)
# Out:
# (201210, 34)

# %%
from scipy.stats.mstats import winsorize

#  Filter rows within 2nd and 98th percentiles
lower_bound = df["daily_decr30"].quantile(0.04)
upper_bound = df["daily_decr30"].quantile(0.96)

df = df[(df["daily_decr30"] >= lower_bound) & (df["aon"] <= upper_bound)]

#  Cap extreme values (Winsorization) on remaining data
df["daily_decr30"] = winsorize(df["daily_decr30"], limits=[0.01, 0.01])  # Cap at 1% from each side

df = df.reset_index(drop=True)
print(df.shape)
# Out:
# (193186, 34)

# %%
from scipy.stats.mstats import winsorize

#  Filter rows within 2nd and 98th percentiles
lower_bound = df["daily_decr90"].quantile(0.02)
upper_bound = df["daily_decr90"].quantile(0.98)
df = df[(df["daily_decr90"] >= lower_bound) & (df["aon"] <= upper_bound)]

#  Cap extreme values (Winsorization) on remaining data
df["daily_decr90"] = winsorize(df["daily_decr90"], limits=[0.01, 0.01])  # Cap at 1% from each side

df = df.reset_index(drop=True)
print(df.shape)
# Out:
# (189326, 34)

# %%
from scipy.stats.mstats import winsorize

#  Filter rows within 2nd and 98th percentiles
lower_bound = df["rental30"].quantile(0.02)
upper_bound = df["rental30"].quantile(0.98)
df = df[(df["rental30"] >= lower_bound) & (df["rental30"] <= upper_bound)]

#  Cap extreme values (Winsorization) on remaining data
df["rental30"] = winsorize(df["rental30"], limits=[0.01, 0.01])  # Cap at 1% from each side

df = df.reset_index(drop=True)
print(df.shape)
# Out:
# (181754, 34)

# %%
from scipy.stats.mstats import winsorize

# Step 1: Filter rows within 2nd and 98th percentiles
lower_bound = df["rental90"].quantile(0.02)
upper_bound = df["rental90"].quantile(0.98)
df = df[(df["rental90"] >= lower_bound) & (df["rental30"] <= upper_bound)]

# Step 2: Cap extreme values (Winsorization) on remaining data
df["rental90"] = winsorize(df["rental90"], limits=[0.01, 0.01])  # Cap at 1% from each side

df = df.reset_index(drop=True)
print(df.shape)
# Out:
# (179908, 34)

# %%
df.head()
# Out:
#    label   msisdn    aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0      0  21408.0  272.0   3055.050000   3065.150000    220.13    260.13
# 1      1  76462.0  712.0  12122.000000  12124.750000   3691.26   3691.26
# 2      1  17943.0  535.0   1398.000000   1398.000000    900.13    900.13
# 3      1  55773.0  241.0     21.228000     21.228000    159.42    159.42
# 4      1   3813.0  947.0    150.619333    150.619333   1098.90   1098.90
#
#    last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  \
# 0                2.0                0.0              1539              2
# 1               20.0                0.0              5787              1
# 2                3.0                0.0              1539              1
# 3               41.0                0.0               947              0
# 4                4.0                0.0              2309              7
#
#    fr_ma_rech30  sumamnt_ma_rech30  medianamnt_ma_rech30  \
# ...

# %%
plt.figure(figsize=(20,20))
graph=1
for num in df[:34]:
    plt.subplot(6,6,graph)
    sns.boxplot(data=df[num],orient="v")
    plt.xlabel(num,fontsize=12)
    graph+=1
plt.show()

# %%
# Ensure your DataFrame is cleaned and prepped as needed
#sns.pairplot(df)

# %%
# print the histplot
#plt.figure(figsize=(20,20))
#graph=1
#for num in df[:34]:
#    plt.subplot(6,5,graph)
 #   sns.histplot(data=df[num],kde=True)
  #  plt.xlabel(num,fontsize=12)
   # graph+=1
#plt.show()

# %% [markdown]
# # DATA PREPROCESSING

# %%
# dependent feature in X
X=df.drop(columns=["label"],axis=1)

#  targget feature in y
y=df["label"] #  targget feature in y

# %%
x=X

# %% [markdown]
# # STANDIZATION AND NORMALIZATION

# %%
# IMPORT LIBERARYY of minmaxscaler , PowerTransform
from sklearn.preprocessing import MinMaxScaler , PowerTransformer
# powertransform of X data
ptf=PowerTransformer(method='yeo-johnson')

# %%
# fit_transfform x data
x_ptf=ptf.fit_transform(X)

# %%
# create a dataframe
x=pd.DataFrame(x_ptf,columns=x.columns)
x.head()
# Out:
#      msisdn       aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0 -0.925104 -0.751420      0.382850      0.360105 -0.961077 -0.956099
# 1  0.913262  0.411795      1.074821      1.020788  0.785167  0.596820
# 2 -1.074135  0.042737      0.037802      0.024816 -0.222348 -0.334022
# 3  0.296363 -0.882496     -1.342292     -1.342149 -1.100426 -1.160538
# 4 -1.825561  0.801580     -0.785779     -0.783927 -0.098018 -0.218267
#
#    last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  \
# 0          -0.029600          -0.077959          0.007195      -0.412377
# 1           0.187164          -0.077959          1.606037      -0.959184
# 2          -0.004067          -0.077959          0.007195      -0.959184
# 3           0.295155          -0.077959         -0.412126      -1.883198
# 4           0.017103          -0.077959          0.418524       0.929857
#
#    fr_ma_rech30  sumamnt_ma_rech30  medianamnt_ma_rech30  \
# ...

# %%
# Scale the features use of minmaxscaler
import pandas as pd
import numpy as np
originals_colummns=x.columns
scaler = MinMaxScaler()
x_scale = scaler.fit_transform(x)
x=pd.DataFrame(x_scale,columns=x.columns)

# %%
x.head()
# Out:
#      msisdn       aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0  0.340867  0.304095      0.600752      0.578550  0.319005  0.322373
# 1  0.829252  0.612535      0.794327      0.768497  0.709262  0.664910
# 2  0.301275  0.514675      0.504227      0.482153  0.484099  0.459589
# 3  0.665365  0.269339      0.118154      0.089149  0.287863  0.277279
# 4  0.101649  0.715891      0.273835      0.249639  0.511885  0.485121
#
#    last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  \
# 0           0.610179            0.96156          0.260924       0.222288
# 1           0.619839            0.96156          0.432833       0.139648
# 2           0.611316            0.96156          0.260924       0.139648
# 3           0.624651            0.96156          0.215839       0.000000
# 4           0.612260            0.96156          0.305151       0.425142
#
#    fr_ma_rech30  sumamnt_ma_rech30  medianamnt_ma_rech30  \
# ...

# %% [markdown]
# # vif(varience influence factor) for multicolinearity

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif["vif"]=[variance_inflation_factor(x_scale,i) for i in range(x_scale.shape[1])]
vif["features"]=x.columns
vif
# Out:
#             vif              features
# 0      5.876979                msisdn
# 1      4.735570                   aon
# 2   1433.925955          daily_decr30
# 3   1366.683105          daily_decr90
# 4    140.030322              rental30
# 5    161.850297              rental90
# 6    191.122550     last_rech_date_ma
# 7    404.770777     last_rech_date_da
# 8     33.110404      last_rech_amt_ma
# 9    208.434856         cnt_ma_rech30
# 10     4.491458          fr_ma_rech30
# 11   345.760949     sumamnt_ma_rech30
# 12    71.926527  medianamnt_ma_rech30
# 13   155.069495  medianmarechprebal30
# 14   252.947696         cnt_ma_rech90
# 15     4.513057          fr_ma_rech90
# 16   387.619268     sumamnt_ma_rech90
# 17    91.958754  medianamnt_ma_rech90
# 18    82.325686  medianmarechprebal90
# 19     1.866118         cnt_da_rech30
# 20     1.254871          fr_da_rech30
# 21     1.837425         cnt_da_rech90
# 22     1.489292          fr_da_rech90
# 23   778.341987           cnt_loans30
# ...

# %% [markdown]
# # to remoove the multicolenearity with PCA

# %%
from sklearn.decomposition import PCA

# Initialize PCA and fit to the data
pca = PCA(n_components=14)  # use of 14 importent feature
x_pca = pca.fit_transform(x)

x = pd.DataFrame(x_pca)
x.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0 -0.384415 -0.610396  0.197078 -0.241044  0.128562  0.276027  0.545044
# 1  0.120439  0.785441 -0.278195  0.068379 -0.138021 -0.262985  0.024275
# 2  0.573960  0.406416 -0.274619  0.099880  0.282293  0.078305  0.104426
# 3  0.953391 -0.082164 -0.295432  0.247193 -0.145343  0.109133 -0.003788
# 4 -0.161848 -0.392602 -0.102505  0.109385  0.506683  0.097408 -0.420282
#
#          7         8         9         10        11        12        13
# 0 -0.243032 -0.050131  0.132250  0.084549 -0.107420 -0.054724 -0.036724
# 1 -0.002017 -0.034362  0.096090 -0.170053 -0.425179 -0.097187 -0.038602
# 2 -0.009692 -0.043415  0.093063 -0.019051 -0.058589 -0.072632  0.015237
# 3 -0.029714 -0.003459 -0.166120 -0.037184 -0.046823 -0.060268  0.160242
# 4  0.019816  0.003366  0.068028 -0.059685  0.030076 -0.037690  0.078933

# %%
# checck the shape of dataset after use PCA
x.shape
# Out:
# (179908, 14)

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 179908 entries, 0 to 179907
# Data columns (total 14 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   0       179908 non-null  float64
#  1   1       179908 non-null  float64
#  2   2       179908 non-null  float64
#  3   3       179908 non-null  float64
#  4   4       179908 non-null  float64
#  5   5       179908 non-null  float64
#  6   6       179908 non-null  float64
#  7   7       179908 non-null  float64
#  8   8       179908 non-null  float64
#  9   9       179908 non-null  float64
#  10  10      179908 non-null  float64
#  11  11      179908 non-null  float64
#  12  12      179908 non-null  float64
#  13  13      179908 non-null  float64
# dtypes: float64(14)
# memory usage: 19.2 MB

# %% [markdown]
# # CHECK RANDOM STATE FOR TRAIN_TEST_SPLIT

# %%
# check the random state for train_test_split

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

# use of logisticregresssionn
lr = LogisticRegression()


for i in range(0, 150):
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=i)
    lr.fit(x_train, y_train)

    pred_train = lr.predict(x_train)
    pred_test = lr.predict(x_test)

    train_r2 = accuracy_score(y_train, pred_train) * 100
    test_r2 = accuracy_score(y_test, pred_test) * 100

    # checck condition train and test data
    if round(train_r2, 1) == round(test_r2, 1):
        print("Random state:", i)
        print("Training accuracy_score:", train_r2)
        print("Testing accuracy_score:", test_r2)
# Out:
# Random state: 2
# Training accuracy_score: 90.87864597084612
# Testing accuracy_score: 90.8843310544161
# Random state: 3
# Training accuracy_score: 90.86058113197059
# Testing accuracy_score: 90.94825190372964
# Random state: 5
# Training accuracy_score: 90.87586676486528
# Testing accuracy_score: 90.87877271969317
# Random state: 6
# Training accuracy_score: 90.86266553645623
# Testing accuracy_score: 90.92879773219943
# Random state: 7
# Training accuracy_score: 90.87517196337006
# Testing accuracy_score: 90.87599355233172
# Random state: 20
# Training accuracy_score: 90.87517196337006
# Testing accuracy_score: 90.90378522594631
# Random state: 21
# Training accuracy_score: 90.86683434542752
# Testing accuracy_score: 90.94269356900672
# Random state: 22
# Training accuracy_score: 90.87030835290358
# Testing accuracy_score: 90.92879773219943
# Random state: 23
# Training accuracy_score: 90.87725636785571
# Testing accuracy_score: 90.8648768828859
# Random state: 29
# ...

# %% [markdown]
# random state = 56

# %%
# split data of train and test
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=56)

# check the shaape of train and test data
print("shape of x_train",x_train.shape)
print("shape of x_test",x_test.shape)
print("shape of y_train",y_train.shape)
print("shape of y_test",y_test.shape)
# Out:
# shape of x_train (143926, 14)
# shape of x_test (35982, 14)
# shape of y_train (143926,)
# shape of y_test (35982,)

# %% [markdown]
# # CHECK THE ENBALANCING DATASET

# %%
from imblearn.over_sampling import SMOTE
from collections import Counter

# %%
# check count calue of y_train
print(y_train.value_counts())
# Out:
# label
# 1    130756
# 0     13170
# Name: count, dtype: int64

# %%
Counter(y_train)
# Out:
# Counter({1: 130756, 0: 13170})

# %%
from imblearn.over_sampling import SMOTE
from collections import Counter

# Define the SMOTE instance with a sampling strategy of 0.8
R_SMP = SMOTE(sampling_strategy=0.80)

# Apply SMOTE to the training data
x_train_ns, y_train_ns = R_SMP.fit_resample(x_train, y_train)

# Print the class distribution before and after SMOTE
print("Before resampling, class distribution:", Counter(y_train))
print("After resampling, class distribution:", Counter(y_train_ns))
# Out:
# Before resampling, class distribution: Counter({1: 130756, 0: 13170})
# After resampling, class distribution: Counter({1: 130756, 0: 104604})

# %% [markdown]
# # Trained the model

# %% [markdown]
# # LOGISTICREGRESSION

# %%
# firstt use of logistic regression alggorithom
from sklearn.metrics import accuracy_score , confusion_matrix
from sklearn.metrics import classification_report
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()

# fit x_train and y_train
lr.fit(x_train_ns,y_train_ns)
# predict the x_test
pred_lr=lr.predict(x_test)

#CHECCK THE ACCURACy amd confussion matrix or classification report OF GBC
print("check the accuracy of model\n",accuracy_score(y_test,pred_lr))
print("confussion metrix\n",confusion_matrix(y_test,pred_lr))
print("classification report\n",classification_report(y_test,pred_lr))
# Out:
# check the accuracy of model
#  0.7626035239842144
# confussion metrix
#  [[ 2137  1119]
#  [ 7423 25303]]
# classification report
#                precision    recall  f1-score   support
#
#            0       0.22      0.66      0.33      3256
#            1       0.96      0.77      0.86     32726
#
#     accuracy                           0.76     35982
#    macro avg       0.59      0.71      0.59     35982
# weighted avg       0.89      0.76      0.81     35982

# %% [markdown]
# # SVC

# %% [raw]
# ##support vector classifire
# #from sklearn.svm import SVC
# #svc=SVC()
#
# # fit x_train and y_train
# #svc.fit(x_train_ns,y_train_ns)
#
# # predict the x_test
# #pred_svc=svc.predict(x_test)
#
# #CHECCK THE ACCURACy amd confussion matrix or classification report OF GBC
# #print("check the accuracy of model\n",accuracy_score(y_test,pred_svc))
# #print("confussion metrix\n",confusion_matrix(y_test,pred_svc))
# #print("classification report\n",classification_report(y_test,pred_svc))

# %% [markdown]
# # GradientBoostingClassifier CLASSIFIER

# %%
# use of gradiant boosting algorithom
#  It combines multiple weak learners (typically decision trees) in a sequential manner
from sklearn.ensemble import GradientBoostingClassifier
gbc=GradientBoostingClassifier()

# fit the gbc model
gbc.fit(x_train_ns,y_train_ns)

# PREDICCT THE X TEST
pred_gbc=gbc.predict(x_test)


#CHECCK THE ACCURACy amd confussion matrix or classification report OF GBC
print("accuracy of gbc",accuracy_score(y_test,pred_gbc))
# CONFUSIONN MATRIX
print("accuracy of gbc",confusion_matrix(y_test,pred_gbc))
# CLASSSIFICCATION REPORT
print("accuracy of gbc",classification_report(y_test,pred_gbc))
# Out:
# accuracy of gbc 0.7773886943471736
# accuracy of gbc [[ 2241  1015]
#  [ 6995 25731]]
# accuracy of gbc               precision    recall  f1-score   support
#
#            0       0.24      0.69      0.36      3256
#            1       0.96      0.79      0.87     32726
#
#     accuracy                           0.78     35982
#    macro avg       0.60      0.74      0.61     35982
# weighted avg       0.90      0.78      0.82     35982

# %% [markdown]
# # random forest classification

# %%
#  It constructs a multitude of decision trees during training and outputs the mode
#  because they reduce overfitting and improve accuracy.
from sklearn.ensemble import RandomForestClassifier
RF=RandomForestClassifier()

# fit the gbc model
RF.fit(x_train_ns,y_train_ns)

# PREDICCT THE X TEST
pred_RF=RF.predict(x_test)

#CHECCK THE ACCURACy amd confussion matrix or classification report OF GBC
print("accuracy of gbc",accuracy_score(y_test,pred_RF))

# CONFUSIONN MATRIX
print("accuracy of gbc",confusion_matrix(y_test,pred_RF))

# CLASSSIFICCATION REPORT
print("accuracy of gbc",classification_report(y_test,pred_RF))
# Out:
# accuracy of gbc 0.8779945528319716
# accuracy of gbc [[ 1521  1735]
#  [ 2655 30071]]
# accuracy of gbc               precision    recall  f1-score   support
#
#            0       0.36      0.47      0.41      3256
#            1       0.95      0.92      0.93     32726
#
#     accuracy                           0.88     35982
#    macro avg       0.65      0.69      0.67     35982
# weighted avg       0.89      0.88      0.88     35982

# %% [markdown]
# # DECISSION TREE CLASSIFIER

# %%
# Decission tree
# decission  splits the data into subsets based on feature values, creating a "tree" structure
from sklearn.tree import DecisionTreeClassifier
DT=DecisionTreeClassifier()

#fit the model
DT.fit(x_train_ns,y_train_ns)
pre=DT.predict(x_test)

#CHECCK THE ACCURACy amd confussion matrix or classification report OF GBC
print("accuracy of model\n",accuracy_score(y_test,pre))
print("confussion metrix\n",confusion_matrix(y_test,pre))
print("classification report\n",classification_report(y_test,pre))
# Out:
# accuracy of model
#  0.8110722027680507
# confussion metrix
#  [[ 1460  1796]
#  [ 5002 27724]]
# classification report
#                precision    recall  f1-score   support
#
#            0       0.23      0.45      0.30      3256
#            1       0.94      0.85      0.89     32726
#
#     accuracy                           0.81     35982
#    macro avg       0.58      0.65      0.60     35982
# weighted avg       0.87      0.81      0.84     35982

# %% [markdown]
# # XGBClassifier

# %%
# xgboost classsifier
# XGBClassifier is a highly efficient and powerful implementation of gradient boosting,
from xgboost import XGBClassifier
xgb=XGBClassifier()

# fit the model
xgb.fit(x_train_ns,y_train_ns)
pre_xgb=xgb.predict(x_test)

#CHECCK THE ACCURACy amd confussion matrix or classification report OF GBC
print("accuracy of model\n",accuracy_score(y_test,pre_xgb))
print("confussion metrix\n",confusion_matrix(y_test,pre_xgb))
print("classification report\n",classification_report(y_test,pre_xgb))
# Out:
# accuracy of model
#  0.8079317436496026
# confussion metrix
#  [[ 2202  1054]
#  [ 5857 26869]]
# classification report
#                precision    recall  f1-score   support
#
#            0       0.27      0.68      0.39      3256
#            1       0.96      0.82      0.89     32726
#
#     accuracy                           0.81     35982
#    macro avg       0.62      0.75      0.64     35982
# weighted avg       0.90      0.81      0.84     35982

# %% [markdown]
# #  SGDClassifier

# %%
from sklearn.linear_model import SGDClassifier
sgd=SGDClassifier()
 #fit the gbc model
sgd.fit(x_train_ns,y_train_ns)
# PREDICCT THE X TEST
pred_sgd=sgd.predict(x_test)

#CHECCK THE ACCURACy amd confussion matrix or classification report OF GBC
print("accuracy of gbc",accuracy_score(y_test,pred_sgd))
# CONFUSIONN MATRIX
print("accuracy of gbc",confusion_matrix(y_test,pred_sgd))
# CLASSSIFICCATION REPORT
print("accuracy of gbc",classification_report(y_test,pred_RF))
# Out:
# accuracy of gbc 0.7747762770274026
# accuracy of gbc [[ 1956  1300]
#  [ 6804 25922]]
# accuracy of gbc               precision    recall  f1-score   support
#
#            0       0.36      0.47      0.41      3256
#            1       0.95      0.92      0.93     32726
#
#     accuracy                           0.88     35982
#    macro avg       0.65      0.69      0.67     35982
# weighted avg       0.89      0.88      0.88     35982

# %% [markdown]
# # neural_network

# %%
# sklearn.neural_network module is a multi-layer perceptron (MLP) model that can be used for classification tasks.
#It is a type of feedforward artificial neural network that can learn complex patterns in data.
#from sklearn.neural_network import MLPClassifier
#mlp=MLPClassifier()
#mlp.fit(x_train_ns,y_train_ns)
#pre_mlp=mlp.predict(x_test)
#print("accuracy of model\n",accuracy_score(y_test,pre_mlp))
#print("confussion metrix\n",confusion_matrix(y_test,pre_mlp))
#print("classification report\n",classification_report(y_test,pre_mlp))

# %% [markdown]
# # KNeighborsClassifier

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier()

knn.fit(x_train_ns,y_train_ns)
pred_knn=knn.predict(x_test)

print("accuracy of model\n",accuracy_score(y_test,pred_knn))
print("confussion metrix\n",confusion_matrix(y_test,pred_knn))
print("classification report\n",classification_report(y_test,pred_knn))
# Out:
# accuracy of model
#  0.7835584458896114
# confussion metrix
#  [[ 1850  1406]
#  [ 6382 26344]]
# classification report
#                precision    recall  f1-score   support
#
#            0       0.22      0.57      0.32      3256
#            1       0.95      0.80      0.87     32726
#
#     accuracy                           0.78     35982
#    macro avg       0.59      0.69      0.60     35982
# weighted avg       0.88      0.78      0.82     35982

# %% [markdown]
# # CROSSVALIDATION

# %% [markdown]
# LOGISTIC REGRESSION

# %%
# logistic regression
from sklearn.model_selection import cross_val_score

scr=cross_val_score(lr,x_train_ns,y_train_ns,cv=5)
# mean value
print("score of after crossvalidation",scr.mean())
# Out:
# score of after crossvalidation 0.7201521074099252

# %% [markdown]
#  grediantboosting

# %%
#  crossvalidattion of grediantboosting grediantboosting
from sklearn.model_selection import cross_val_score

scr=cross_val_score(gbc,x_train_ns,y_train_ns,cv=5)

print("score of after crossvalidation",scr.mean())
# Out:
# score of after crossvalidation 0.7563774643099933

# %% [markdown]
# RANDOMFOREST

# %%
#  crossvalidattion of RANDOMFOREST algorithom
from sklearn.model_selection import cross_val_score

scr=cross_val_score(RF,x_train_ns,y_train_ns,cv=3)

print("score of after crossvalidation",scr.mean())
# Out:
# score of after crossvalidation 0.9099124867072487

# %% [markdown]
# DECISIONTREECLASSIFIRE

# %%
#  crossvalidattion of DECISIONTREECLASSIFIRE algorithom
from sklearn.model_selection import cross_val_score

scr=cross_val_score(DT,x_train_ns,y_train_ns,cv=3)

print("score of after crossvalidation",scr.mean())
# Out:
# score of after crossvalidation 0.8319553144418071

# %% [markdown]
# xgbosost

# %%
#  crossvalidattion of xgbosost algorithom
from sklearn.model_selection import cross_val_score

scr=cross_val_score(xgb,x_train_ns,y_train_ns,cv=3)

print("score of after crossvalidation",scr.mean())
# Out:
# score of after crossvalidation 0.8131373402273628

# %% [markdown]
# SGDClassifier

# %%
#  crossvalidattion of #  SGDClassifier algorithom
from sklearn.model_selection import cross_val_score

scr=cross_val_score(sgd,x_train_ns,y_train_ns,cv=3)

print("score of after crossvalidation",scr.mean())
# Out:
# score of after crossvalidation 0.7112593586008463

# %% [markdown]
# KNeighborsClassifier

# %%
#  crossvalidattion of #  KNeighborsClassifier algorithom
from sklearn.model_selection import cross_val_score

scr=cross_val_score(knn,x_train_ns,y_train_ns,cv=3)

print("score of after crossvalidation",scr.mean())
# Out:
# score of after crossvalidation 0.8703305568435077

# %% [markdown]
# # * Apply Hyperparameter Tuninig

# %% [markdown]
# # XGBCLASSIFIER

# %%
# Create an XGBoost model
gsv = XGBClassifier()

from sklearn.model_selection import RandomizedSearchCV
# Define the parameter grid
param_grid = {
    'n_estimators': [100, 200],
    'learning_rate': [0.01, 0.1, 0.2],
    'max_depth': [3, 5, 7],
    'min_child_weight': [1, 3, 5],
    'subsample': [0.6, 0.8, 1.0],
    'colsample_bytree': [0.6, 0.8, 1.0]
    #gamma
}


# Set up the random search
random_search = RandomizedSearchCV(estimator=gsv, param_distributions=param_grid,
                                    n_iter=10, scoring='accuracy', cv=3, verbose=1, n_jobs=-1, random_state=42)


# Fit the random search
random_search.fit(x_train_ns, y_train_ns)


# Get the best parameters
best_params = random_search.best_params_
print("Best parameters found: ", best_params)


#  you can evaluate the model on the test set
best_model = random_search.best_estimator_
predictions = best_model.predict(x_test)


print("accuracy_score:/n",accuracy_score(y_test,predictions))
print("confusion_metrics:/n",confusion_matrix(y_test,predictions))
print("classification_report:/n",classification_report(y_test,predictions))
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Best parameters found:  {'subsample': 0.8, 'n_estimators': 200, 'min_child_weight': 3, 'max_depth': 7, 'learning_rate': 0.1, 'colsample_bytree': 0.8}
# accuracy_score:/n 0.814935245400478
# confusion_metrics:/n [[ 2200  1056]
#  [ 5603 27123]]
# classification_report:/n               precision    recall  f1-score   support
#
#            0       0.28      0.68      0.40      3256
#            1       0.96      0.83      0.89     32726
#
#     accuracy                           0.81     35982
#    macro avg       0.62      0.75      0.64     35982
# weighted avg       0.90      0.81      0.85     35982

# %% [markdown]
# # DecisionTreeClassifier

# %%
# Create an DECISSIONTREECLASSIFIR model
DT=DecisionTreeClassifier()

from sklearn.model_selection import RandomizedSearchCV
# Define the parameter

param_grid = {
    'max_depth': [3, 5, 10, 15, 20],
    'min_samples_split': [2, 5, 10, 20],
    'min_samples_leaf': [1, 2, 5, 10],
    'max_features': ['sqrt', 'log2', None],
    'max_leaf_nodes': [None, 10, 20, 50, 100],
    'criterion': ['gini', 'entropy'],
    'min_impurity_decrease': [0.0, 0.01, 0.05],
}



# Set up the random search
random_search = RandomizedSearchCV(estimator=DT, param_distributions=param_grid,
                                    n_iter=50, scoring='accuracy', cv=5, verbose=1, n_jobs=-1, random_state=42)


# Fit the random search
random_search.fit(x_train_ns, y_train_ns)


# Get the best parameters
best_params_dt = random_search.best_params_
print("Best parameters found: ", best_params_dt)


#  you can evaluate the model on the test set
best_model_dt = random_search.best_estimator_
predictions_dt = best_model_dt.predict(x_test)


print("accuracy_score:/n",accuracy_score(y_test,predictions_dt))
print("confusion_metrics:/n",confusion_matrix(y_test,predictions_dt))
print("classification_report:/n",classification_report(y_test,predictions_dt))
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Best parameters found:  {'min_samples_split': 20, 'min_samples_leaf': 10, 'min_impurity_decrease': 0.0, 'max_leaf_nodes': None, 'max_features': None, 'max_depth': 20, 'criterion': 'entropy'}
# accuracy_score:/n 0.7910621977655494
# confusion_metrics:/n [[ 1916  1340]
#  [ 6178 26548]]
# classification_report:/n               precision    recall  f1-score   support
#
#            0       0.24      0.59      0.34      3256
#            1       0.95      0.81      0.88     32726
#
#     accuracy                           0.79     35982
#    macro avg       0.59      0.70      0.61     35982
# weighted avg       0.89      0.79      0.83     35982

# %% [markdown]
# # GradientBoostingClassifier

# %%
#Create an GRADIANTBOOSTING CLASSIFIER model
GBC=GradientBoostingClassifier()

from sklearn.model_selection import RandomizedSearchCV
 #Define the parameter grid

param_grid = {
   'n_estimators': [100, 200],
   'learning_rate': [0.01, 0.1],
   'max_depth': [3, 4],
   'min_samples_split': [2, 5],
   'min_samples_leaf': [1, 2],
   'max_features': ['sqrt', None],
   'subsample': [0.8, 1.0],
}



# Set up the random search
random_search_gbc = RandomizedSearchCV(estimator=GBC, param_distributions=param_grid,
                                    n_iter=10, scoring='accuracy', cv=3, verbose=1, n_jobs=-1, random_state=42)


# Fit the random search
random_search_gbc.fit(x_train_ns, y_train_ns)


# Get the best parameters
best_params_gbc = random_search_gbc.best_params_
print("Best parameters found: ", best_params_gbc)


#  you can evaluate the model on the test set
best_model_gbc = random_search_gbc.best_estimator_
predictions_gbc = best_model_gbc.predict(x_test)


print("accuracy_score:/n",accuracy_score(y_test,predictions_gbc))
print("confusion_metrics:/n",confusion_matrix(y_test,predictions_gbc))
print("classification_report:/n",classification_report(y_test,predictions_gbc))
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Best parameters found:  {'subsample': 0.8, 'n_estimators': 200, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'max_depth': 4, 'learning_rate': 0.1}
# accuracy_score:/n 0.7914790728697683
# confusion_metrics:/n [[ 2227  1029]
#  [ 6474 26252]]
# classification_report:/n               precision    recall  f1-score   support
#
#            0       0.26      0.68      0.37      3256
#            1       0.96      0.80      0.87     32726
#
#     accuracy                           0.79     35982
#    macro avg       0.61      0.74      0.62     35982
# weighted avg       0.90      0.79      0.83     35982

# %% [markdown]
# # RandomForestClassifier

# %%
# Create an randomforestclassifuer model
RF=RandomForestClassifier()

from sklearn.model_selection import RandomizedSearchCV
# Define the parameter grid

param_grid = {

    'n_estimators': [100, 200],  # Reduced number of trees
    'max_depth': [None, 10],  # Reduced depth options
    'min_samples_split': [2, 5],  # Reduced min samples to split
    'min_samples_leaf': [1, 2],  # Reduced min samples at a leaf
    'max_features': ['sqrt'],  # Only one option for max features
    'bootstrap': [True],  # Only one option for bootstrapping
}




# Set up the random search
random_search_rf = RandomizedSearchCV(estimator=RF, param_distributions=param_grid,
                                    n_iter=10, scoring='accuracy', cv=5, verbose=1, n_jobs=-1, random_state=42)


# Fit the random search
random_search_rf.fit(x_train_ns, y_train_ns)


# Get the best parameters
best_params_rf = random_search_rf.best_params_
print("Best parameters found: ", )


#  you can evaluate the model on the test set
best_model_rf = random_search_rf.best_estimator_
predictions_rf = best_model_rf.predict(x_test)

best_params_rf
print("accuracy_score:/n",accuracy_score(y_test,predictions_rf))
print("confusion_metrics:/n",confusion_matrix(y_test,predictions_rf))
print("classification_report:/n",classification_report(y_test,predictions_rf))
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Best parameters found:  {'n_estimators': 200, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'max_depth': None, 'bootstrap': True}
# accuracy_score:/n 0.8798010116169196
# confusion_metrics:/n [[ 1511  1745]
#  [ 2580 30146]]
# classification_report:/n               precision    recall  f1-score   support
#
#            0       0.37      0.46      0.41      3256
#            1       0.95      0.92      0.93     32726
#
#     accuracy                           0.88     35982
#    macro avg       0.66      0.69      0.67     35982
# weighted avg       0.89      0.88      0.89     35982

# %% [markdown]
# # knearestClassifier

# %%
# Create an kneigoborcclassifier model
knn=KNeighborsClassifier()

from sklearn.model_selection import RandomizedSearchCV
# Define the parameter grid

param_grid = {

    'n_neighbors': range(5, 30),  # Larger range to prevent overfitting
    'weights': ['uniform', 'distance'],  # Weight closer neighbors more
    'metric': ['euclidean', 'manhattan'],  # Try different distance metrics
}
    #max_features




# Set up the random search
random_search_knn = RandomizedSearchCV(estimator=knn, param_distributions=param_grid,
                                    n_iter=10, scoring='accuracy', cv=5, verbose=1, n_jobs=-1, random_state=42)


# Fit the random search
random_search_knn.fit(x_train_ns, y_train_ns)


# Get the best parameters
best_params_knn = random_search_knn.best_params_
print("Best parameters found: ", best_params_knn)


#  you can evaluate the model on the test set
best_model_knn = random_search_knn.best_estimator_
predictions_rf = best_model_knn.predict(x_test)


print("accuracy_score:/n",accuracy_score(y_test,predictions_rf))
print("confusion_metrics:/n",confusion_matrix(y_test,predictions_rf))
print("classification_report:/n",classification_report(y_test,predictions_rf))
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Best parameters found:  {'weights': 'distance', 'n_neighbors': 6, 'metric': 'manhattan'}
# accuracy_score:/n 0.7960646990161747
# confusion_metrics:/n [[ 1843  1413]
#  [ 5925 26801]]
# classification_report:/n               precision    recall  f1-score   support
#
#            0       0.24      0.57      0.33      3256
#            1       0.95      0.82      0.88     32726
#
#     accuracy                           0.80     35982
#    macro avg       0.59      0.69      0.61     35982
# weighted avg       0.89      0.80      0.83     35982

# %% [markdown]
# # RANDOMFORESTCLASSIFIER IS THE BEST MODEL WITH HYPERPARAMETER TUNING and crossvalidation

# %% [markdown]
# # save the best model

# %%
# using pickle
import pickle

# Save the model to a file
with open("best_model_rf.pkl", "wb") as file:
    pickle.dump(best_model_rf, file)

print("Model saved to best_model_rf.pkl")


# Load the model from the file
with open("best_model_rf.pkl", "rb") as file:
    loaded_model_rf = pickle.load(file)

loaded_model_rf.predict(x_test)
# Out:
# Model saved to best_model_rf.pkl
# array([1, 1, 1, ..., 1, 1, 1], dtype=int64)
