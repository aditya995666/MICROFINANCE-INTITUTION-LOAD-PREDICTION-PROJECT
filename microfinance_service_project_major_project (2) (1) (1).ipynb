# %%
# import liberary
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# read dataset
df=pd.read_csv(r"Micro-credit-Data-file .csv")
# print the top head
df.head()
# Out:
#    Unnamed: 0  label       msisdn    aon  daily_decr30  daily_decr90  \
# 0           1      0  21408I70789  272.0   3055.050000   3065.150000
# 1           2      1  76462I70374  712.0  12122.000000  12124.750000
# 2           3      1  17943I70372  535.0   1398.000000   1398.000000
# 3           4      1  55773I70781  241.0     21.228000     21.228000
# 4           5      1  03813I82730  947.0    150.619333    150.619333
#
#    rental30  rental90  last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  \
# 0    220.13    260.13                2.0                0.0              1539
# 1   3691.26   3691.26               20.0                0.0              5787
# 2    900.13    900.13                3.0                0.0              1539
# 3    159.42    159.42               41.0                0.0               947
# 4   1098.90   1098.90                4.0                0.0              2309
#
#    cnt_ma_rech30  fr_ma_rech30  sumamnt_ma_rech30  medianamnt_ma_rech30  \
# 0              2          21.0             3078.0                1539.0
# 1              1           0.0             5787.0                5787.0
# 2              1           0.0             1539.0                1539.0
# 3              0           0.0                0.0                   0.0
# 4              7           2.0            20029.0                2309.0
#
#    medianmarechprebal30  cnt_ma_rech90  fr_ma_rech90  sumamnt_ma_rech90  \
# 0                  7.50              2            21               3078
# 1                 61.04              1             0               5787
# 2                 66.32              1             0               1539
# 3                  0.00              1             0                947
# 4                 29.00              8             2              23496
#
#    medianamnt_ma_rech90  medianmarechprebal90  cnt_da_rech30  fr_da_rech30  \
# 0                1539.0                  7.50            0.0           0.0
# 1                5787.0                 61.04            0.0           0.0
# 2                1539.0                 66.32            0.0           0.0
# 3                 947.0                  2.50            0.0           0.0
# 4                2888.0                 35.00            0.0           0.0
#
#    cnt_da_rech90  fr_da_rech90  cnt_loans30  amnt_loans30  maxamnt_loans30  \
# 0              0             0            2            12              6.0
# 1              0             0            1            12             12.0
# 2              0             0            1             6              6.0
# 3              0             0            2            12              6.0
# 4              0             0            7            42              6.0
#
#    medianamnt_loans30  cnt_loans90  amnt_loans90  maxamnt_loans90  \
# 0                 0.0          2.0            12                6
# 1                 0.0          1.0            12               12
# 2                 0.0          1.0             6                6
# 3                 0.0          2.0            12                6
# 4                 0.0          7.0            42                6
#
#    medianamnt_loans90  payback30  payback90 pcircle      pdate
# 0                 0.0  29.000000  29.000000     UPW  7/20/2016
# 1                 0.0   0.000000   0.000000     UPW  8/10/2016
# 2                 0.0   0.000000   0.000000     UPW  8/19/2016
# 3                 0.0   0.000000   0.000000     UPW   6/6/2016
# 4                 0.0   2.333333   2.333333     UPW  6/22/2016

# %%
# print the bottom
df.tail()
# Out:
#         Unnamed: 0  label       msisdn     aon  daily_decr30  daily_decr90  \
# 209588      209589      1  22758I85348   404.0    151.872333    151.872333
# 209589      209590      1  95583I84455  1075.0     36.936000     36.936000
# 209590      209591      1  28556I85350  1013.0  11843.111670  11904.350000
# 209591      209592      1  59712I82733  1732.0  12488.228330  12574.370000
# 209592      209593      1  65061I85339  1581.0   4489.362000   4534.820000
#
#         rental30  rental90  last_rech_date_ma  last_rech_date_da  \
# 209588   1089.19   1089.19                1.0                0.0
# 209589   1728.36   1728.36                4.0                0.0
# 209590   5861.83   8893.20                3.0                0.0
# 209591    411.83    984.58                2.0               38.0
# 209592    483.92    631.20               13.0                0.0
#
#         last_rech_amt_ma  cnt_ma_rech30  fr_ma_rech30  sumamnt_ma_rech30  \
# 209588              4048              3           2.0            10404.0
# 209589               773              4           1.0             3092.0
# 209590              1539              5           8.0             9334.0
# 209591               773              5           4.0            12154.0
# 209592              7526              2           1.0             9065.0
#
#         medianamnt_ma_rech30  medianmarechprebal30  cnt_ma_rech90  \
# 209588                3178.0                 91.81              3
# 209589                 773.0                161.30              6
# 209590                1539.0                 51.13             11
# 209591                 773.0                164.00              6
# 209592                4532.5                356.70              3
#
#         fr_ma_rech90  sumamnt_ma_rech90  medianamnt_ma_rech90  \
# 209588             2              10404                3178.0
# 209589             2               4038                 773.0
# 209590             5              18592                1539.0
# 209591             4              17941                2410.5
# 209592            19              16591                7526.0
#
#         medianmarechprebal90  cnt_da_rech30  fr_da_rech30  cnt_da_rech90  \
# 209588                 91.81            0.0           0.0              0
# 209589                111.80            0.0           0.0              0
# 209590                 47.13            0.0           0.0              0
# 209591                100.00            0.0           0.0              1
# 209592                392.20            0.0           0.0              0
#
#         fr_da_rech90  cnt_loans30  amnt_loans30  maxamnt_loans30  \
# 209588             0            2            12              6.0
# 209589             0            3            18              6.0
# 209590             0            4            42             12.0
# 209591             0            2            18             12.0
# 209592             0            2            18             12.0
#
#         medianamnt_loans30  cnt_loans90  amnt_loans90  maxamnt_loans90  \
# 209588                 0.0          2.0            12                6
# 209589                 0.0          3.0            18                6
# 209590                 0.0          6.0            54               12
# 209591                 0.0          3.0            24               12
# 209592                 0.0          2.0            18               12
#
#         medianamnt_loans90  payback30  payback90 pcircle      pdate
# 209588                 0.0        1.0   1.000000     UPW  6/17/2016
# 209589                 0.0        1.0   1.000000     UPW  6/12/2016
# 209590                 0.0        4.0   3.833333     UPW  7/29/2016
# 209591                 0.0        0.0  10.500000     UPW  7/25/2016
# 209592                 0.0        0.0   0.000000     UPW   7/7/2016

# %%
# print maximum rows and columns from the dataset
pd.set_option("display.max_columns",None)
pd.set_option("display.max_rows",None)

# %%
# print the  all columns in dataset
df.columns
# Out:
# Index(['Unnamed: 0', 'label', 'msisdn', 'aon', 'daily_decr30', 'daily_decr90',
#        'rental30', 'rental90', 'last_rech_date_ma', 'last_rech_date_da',
#        'last_rech_amt_ma', 'cnt_ma_rech30', 'fr_ma_rech30',
#        'sumamnt_ma_rech30', 'medianamnt_ma_rech30', 'medianmarechprebal30',
#        'cnt_ma_rech90', 'fr_ma_rech90', 'sumamnt_ma_rech90',
#        'medianamnt_ma_rech90', 'medianmarechprebal90', 'cnt_da_rech30',
#        'fr_da_rech30', 'cnt_da_rech90', 'fr_da_rech90', 'cnt_loans30',
#        'amnt_loans30', 'maxamnt_loans30', 'medianamnt_loans30', 'cnt_loans90',
#        'amnt_loans90', 'maxamnt_loans90', 'medianamnt_loans90', 'payback30',
#        'payback90', 'pcircle', 'pdate'],
#       dtype='object')

# %%
# check the shape of dataset
df.shape
# Out:
# (209593, 37)

# %%
#check the null value
df.isnull().sum()
# Out:
# Unnamed: 0              0
# label                   0
# msisdn                  0
# aon                     0
# daily_decr30            0
# daily_decr90            0
# rental30                0
# rental90                0
# last_rech_date_ma       0
# last_rech_date_da       0
# last_rech_amt_ma        0
# cnt_ma_rech30           0
# fr_ma_rech30            0
# sumamnt_ma_rech30       0
# medianamnt_ma_rech30    0
# medianmarechprebal30    0
# cnt_ma_rech90           0
# fr_ma_rech90            0
# sumamnt_ma_rech90       0
# medianamnt_ma_rech90    0
# medianmarechprebal90    0
# cnt_da_rech30           0
# fr_da_rech30            0
# cnt_da_rech90           0
# fr_da_rech90            0
# cnt_loans30             0
# amnt_loans30            0
# maxamnt_loans30         0
# medianamnt_loans30      0
# cnt_loans90             0
# amnt_loans90            0
# maxamnt_loans90         0
# medianamnt_loans90      0
# payback30               0
# payback90               0
# pcircle                 0
# pdate                   0
# dtype: int64

# %%
# check the total null value
df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# # No Null value in Dataset

# %%
# check the information in dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209593 entries, 0 to 209592
# Data columns (total 37 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Unnamed: 0            209593 non-null  int64
#  1   label                 209593 non-null  int64
#  2   msisdn                209593 non-null  object
#  3   aon                   209593 non-null  float64
#  4   daily_decr30          209593 non-null  float64
#  5   daily_decr90          209593 non-null  float64
#  6   rental30              209593 non-null  float64
#  7   rental90              209593 non-null  float64
#  8   last_rech_date_ma     209593 non-null  float64
#  9   last_rech_date_da     209593 non-null  float64
#  10  last_rech_amt_ma      209593 non-null  int64
#  11  cnt_ma_rech30         209593 non-null  int64
#  12  fr_ma_rech30          209593 non-null  float64
#  13  sumamnt_ma_rech30     209593 non-null  float64
#  14  medianamnt_ma_rech30  209593 non-null  float64
#  15  medianmarechprebal30  209593 non-null  float64
#  16  cnt_ma_rech90         209593 non-null  int64
#  17  fr_ma_rech90          209593 non-null  int64
#  18  sumamnt_ma_rech90     209593 non-null  int64
#  19  medianamnt_ma_rech90  209593 non-null  float64
#  20  medianmarechprebal90  209593 non-null  float64
#  21  cnt_da_rech30         209593 non-null  float64
#  22  fr_da_rech30          209593 non-null  float64
#  23  cnt_da_rech90         209593 non-null  int64
#  24  fr_da_rech90          209593 non-null  int64
#  25  cnt_loans30           209593 non-null  int64
#  26  amnt_loans30          209593 non-null  int64
#  27  maxamnt_loans30       209593 non-null  float64
#  28  medianamnt_loans30    209593 non-null  float64
#  29  cnt_loans90           209593 non-null  float64
#  30  amnt_loans90          209593 non-null  int64
#  31  maxamnt_loans90       209593 non-null  int64
#  32  medianamnt_loans90    209593 non-null  float64
#  33  payback30             209593 non-null  float64
#  34  payback90             209593 non-null  float64
#  35  pcircle               209593 non-null  object
#  36  pdate                 209593 non-null  object
# dtypes: float64(21), int64(13), object(3)
# memory usage: 59.2+ MB

# %%
# drop unnamed column from the dataset
df=df.drop(columns=["Unnamed: 0"],axis=1)

# %%
# print the head
df.head()
# Out:
#    label       msisdn    aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0      0  21408I70789  272.0   3055.050000   3065.150000    220.13    260.13
# 1      1  76462I70374  712.0  12122.000000  12124.750000   3691.26   3691.26
# 2      1  17943I70372  535.0   1398.000000   1398.000000    900.13    900.13
# 3      1  55773I70781  241.0     21.228000     21.228000    159.42    159.42
# 4      1  03813I82730  947.0    150.619333    150.619333   1098.90   1098.90
#
#    last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  \
# 0                2.0                0.0              1539              2
# 1               20.0                0.0              5787              1
# 2                3.0                0.0              1539              1
# 3               41.0                0.0               947              0
# 4                4.0                0.0              2309              7
#
#    fr_ma_rech30  sumamnt_ma_rech30  medianamnt_ma_rech30  \
# 0          21.0             3078.0                1539.0
# 1           0.0             5787.0                5787.0
# 2           0.0             1539.0                1539.0
# 3           0.0                0.0                   0.0
# 4           2.0            20029.0                2309.0
#
#    medianmarechprebal30  cnt_ma_rech90  fr_ma_rech90  sumamnt_ma_rech90  \
# 0                  7.50              2            21               3078
# 1                 61.04              1             0               5787
# 2                 66.32              1             0               1539
# 3                  0.00              1             0                947
# 4                 29.00              8             2              23496
#
#    medianamnt_ma_rech90  medianmarechprebal90  cnt_da_rech30  fr_da_rech30  \
# 0                1539.0                  7.50            0.0           0.0
# 1                5787.0                 61.04            0.0           0.0
# 2                1539.0                 66.32            0.0           0.0
# 3                 947.0                  2.50            0.0           0.0
# 4                2888.0                 35.00            0.0           0.0
#
#    cnt_da_rech90  fr_da_rech90  cnt_loans30  amnt_loans30  maxamnt_loans30  \
# 0              0             0            2            12              6.0
# 1              0             0            1            12             12.0
# 2              0             0            1             6              6.0
# 3              0             0            2            12              6.0
# 4              0             0            7            42              6.0
#
#    medianamnt_loans30  cnt_loans90  amnt_loans90  maxamnt_loans90  \
# 0                 0.0          2.0            12                6
# 1                 0.0          1.0            12               12
# 2                 0.0          1.0             6                6
# 3                 0.0          2.0            12                6
# 4                 0.0          7.0            42                6
#
#    medianamnt_loans90  payback30  payback90 pcircle      pdate
# 0                 0.0  29.000000  29.000000     UPW  7/20/2016
# 1                 0.0   0.000000   0.000000     UPW  8/10/2016
# 2                 0.0   0.000000   0.000000     UPW  8/19/2016
# 3                 0.0   0.000000   0.000000     UPW   6/6/2016
# 4                 0.0   2.333333   2.333333     UPW  6/22/2016

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209593 entries, 0 to 209592
# Data columns (total 36 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   label                 209593 non-null  int64
#  1   msisdn                209593 non-null  object
#  2   aon                   209593 non-null  float64
#  3   daily_decr30          209593 non-null  float64
#  4   daily_decr90          209593 non-null  float64
#  5   rental30              209593 non-null  float64
#  6   rental90              209593 non-null  float64
#  7   last_rech_date_ma     209593 non-null  float64
#  8   last_rech_date_da     209593 non-null  float64
#  9   last_rech_amt_ma      209593 non-null  int64
#  10  cnt_ma_rech30         209593 non-null  int64
#  11  fr_ma_rech30          209593 non-null  float64
#  12  sumamnt_ma_rech30     209593 non-null  float64
#  13  medianamnt_ma_rech30  209593 non-null  float64
#  14  medianmarechprebal30  209593 non-null  float64
#  15  cnt_ma_rech90         209593 non-null  int64
#  16  fr_ma_rech90          209593 non-null  int64
#  17  sumamnt_ma_rech90     209593 non-null  int64
#  18  medianamnt_ma_rech90  209593 non-null  float64
#  19  medianmarechprebal90  209593 non-null  float64
#  20  cnt_da_rech30         209593 non-null  float64
#  21  fr_da_rech30          209593 non-null  float64
#  22  cnt_da_rech90         209593 non-null  int64
#  23  fr_da_rech90          209593 non-null  int64
#  24  cnt_loans30           209593 non-null  int64
#  25  amnt_loans30          209593 non-null  int64
#  26  maxamnt_loans30       209593 non-null  float64
#  27  medianamnt_loans30    209593 non-null  float64
#  28  cnt_loans90           209593 non-null  float64
#  29  amnt_loans90          209593 non-null  int64
#  30  maxamnt_loans90       209593 non-null  int64
#  31  medianamnt_loans90    209593 non-null  float64
#  32  payback30             209593 non-null  float64
#  33  payback90             209593 non-null  float64
#  34  pcircle               209593 non-null  object
#  35  pdate                 209593 non-null  object
# dtypes: float64(21), int64(12), object(3)
# memory usage: 57.6+ MB

# %%
# ccheck the description of dataset
df.describe()
# Out:
#                label            aon   daily_decr30   daily_decr90  \
# count  209593.000000  209593.000000  209593.000000  209593.000000
# mean        0.875177    8112.343445    5381.402289    6082.515068
# std         0.330519   75696.082531    9220.623400   10918.812767
# min         0.000000     -48.000000     -93.012667     -93.012667
# 25%         1.000000     246.000000      42.440000      42.692000
# 50%         1.000000     527.000000    1469.175667    1500.000000
# 75%         1.000000     982.000000    7244.000000    7802.790000
# max         1.000000  999860.755200  265926.000000  320630.000000
#
#             rental30       rental90  last_rech_date_ma  last_rech_date_da  \
# count  209593.000000  209593.000000       209593.00000      209593.000000
# mean     2692.581910    3483.406534         3755.84780        3712.202921
# std      4308.586781    5770.461279        53905.89223       53374.833430
# min    -23737.140000  -24720.580000          -29.00000         -29.000000
# 25%       280.420000     300.260000            1.00000           0.000000
# 50%      1083.570000    1334.000000            3.00000           0.000000
# 75%      3356.940000    4201.790000            7.00000           0.000000
# max    198926.110000  200148.110000       998650.37770      999171.809400
#
#        last_rech_amt_ma  cnt_ma_rech30   fr_ma_rech30  sumamnt_ma_rech30  \
# count     209593.000000  209593.000000  209593.000000      209593.000000
# mean        2064.452797       3.978057    3737.355121        7704.501157
# std         2370.786034       4.256090   53643.625172       10139.621714
# min            0.000000       0.000000       0.000000           0.000000
# 25%          770.000000       1.000000       0.000000        1540.000000
# 50%         1539.000000       3.000000       2.000000        4628.000000
# 75%         2309.000000       5.000000       6.000000       10010.000000
# max        55000.000000     203.000000  999606.368100      810096.000000
#
#        medianamnt_ma_rech30  medianmarechprebal30  cnt_ma_rech90  \
# count         209593.000000         209593.000000   209593.00000
# mean            1812.817952           3851.927942        6.31543
# std             2070.864620          54006.374433        7.19347
# min                0.000000           -200.000000        0.00000
# 25%              770.000000             11.000000        2.00000
# 50%             1539.000000             33.900000        4.00000
# 75%             1924.000000             83.000000        8.00000
# max            55000.000000         999479.419300      336.00000
#
#         fr_ma_rech90  sumamnt_ma_rech90  medianamnt_ma_rech90  \
# count  209593.000000      209593.000000         209593.000000
# mean        7.716780       12396.218352           1864.595821
# std        12.590251       16857.793882           2081.680664
# min         0.000000           0.000000              0.000000
# 25%         0.000000        2317.000000            773.000000
# 50%         2.000000        7226.000000           1539.000000
# 75%         8.000000       16000.000000           1924.000000
# max        88.000000      953036.000000          55000.000000
#
#        medianmarechprebal90  cnt_da_rech30   fr_da_rech30  cnt_da_rech90  \
# count         209593.000000  209593.000000  209593.000000  209593.000000
# mean              92.025541     262.578110    3749.494447       0.041495
# std              369.215658    4183.897978   53885.414979       0.397556
# min             -200.000000       0.000000       0.000000       0.000000
# 25%               14.600000       0.000000       0.000000       0.000000
# 50%               36.000000       0.000000       0.000000       0.000000
# 75%               79.310000       0.000000       0.000000       0.000000
# max            41456.500000   99914.441420  999809.240100      38.000000
#
#         fr_da_rech90    cnt_loans30   amnt_loans30  maxamnt_loans30  \
# count  209593.000000  209593.000000  209593.000000    209593.000000
# mean        0.045712       2.758981      17.952021       274.658747
# std         0.951386       2.554502      17.379741      4245.264648
# min         0.000000       0.000000       0.000000         0.000000
# 25%         0.000000       1.000000       6.000000         6.000000
# 50%         0.000000       2.000000      12.000000         6.000000
# 75%         0.000000       4.000000      24.000000         6.000000
# max        64.000000      50.000000     306.000000     99864.560860
#
#        medianamnt_loans30    cnt_loans90   amnt_loans90  maxamnt_loans90  \
# count       209593.000000  209593.000000  209593.000000    209593.000000
# mean             0.054029      18.520919      23.645398         6.703134
# std              0.218039     224.797423      26.469861         2.103864
# min              0.000000       0.000000       0.000000         0.000000
# 25%              0.000000       1.000000       6.000000         6.000000
# 50%              0.000000       2.000000      12.000000         6.000000
# 75%              0.000000       5.000000      30.000000         6.000000
# max              3.000000    4997.517944     438.000000        12.000000
#
#        medianamnt_loans90      payback30      payback90
# count       209593.000000  209593.000000  209593.000000
# mean             0.046077       3.398826       4.321485
# std              0.200692       8.813729      10.308108
# min              0.000000       0.000000       0.000000
# 25%              0.000000       0.000000       0.000000
# 50%              0.000000       0.000000       1.666667
# 75%              0.000000       3.750000       4.500000
# max              3.000000     171.500000     171.500000

# %% [markdown]
# # LABELE ENCODING

# %%
# Extract numeric part and convert to float
df["msisdn"] = df["msisdn"].str.extract('(\d+)').astype(float)

# %%
# import the labelincoder
from sklearn.preprocessing import LabelEncoder
la=LabelEncoder()

# %%
#  categrical features
df["pcircle"]=la.fit_transform(df["pcircle"])
df.head()
# Out:
#    label   msisdn    aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0      0  21408.0  272.0   3055.050000   3065.150000    220.13    260.13
# 1      1  76462.0  712.0  12122.000000  12124.750000   3691.26   3691.26
# 2      1  17943.0  535.0   1398.000000   1398.000000    900.13    900.13
# 3      1  55773.0  241.0     21.228000     21.228000    159.42    159.42
# 4      1   3813.0  947.0    150.619333    150.619333   1098.90   1098.90
#
#    last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  \
# 0                2.0                0.0              1539              2
# 1               20.0                0.0              5787              1
# 2                3.0                0.0              1539              1
# 3               41.0                0.0               947              0
# 4                4.0                0.0              2309              7
#
#    fr_ma_rech30  sumamnt_ma_rech30  medianamnt_ma_rech30  \
# 0          21.0             3078.0                1539.0
# 1           0.0             5787.0                5787.0
# 2           0.0             1539.0                1539.0
# 3           0.0                0.0                   0.0
# 4           2.0            20029.0                2309.0
#
#    medianmarechprebal30  cnt_ma_rech90  fr_ma_rech90  sumamnt_ma_rech90  \
# 0                  7.50              2            21               3078
# 1                 61.04              1             0               5787
# 2                 66.32              1             0               1539
# 3                  0.00              1             0                947
# 4                 29.00              8             2              23496
#
#    medianamnt_ma_rech90  medianmarechprebal90  cnt_da_rech30  fr_da_rech30  \
# 0                1539.0                  7.50            0.0           0.0
# 1                5787.0                 61.04            0.0           0.0
# 2                1539.0                 66.32            0.0           0.0
# 3                 947.0                  2.50            0.0           0.0
# 4                2888.0                 35.00            0.0           0.0
#
#    cnt_da_rech90  fr_da_rech90  cnt_loans30  amnt_loans30  maxamnt_loans30  \
# 0              0             0            2            12              6.0
# 1              0             0            1            12             12.0
# 2              0             0            1             6              6.0
# 3              0             0            2            12              6.0
# 4              0             0            7            42              6.0
#
#    medianamnt_loans30  cnt_loans90  amnt_loans90  maxamnt_loans90  \
# 0                 0.0          2.0            12                6
# 1                 0.0          1.0            12               12
# 2                 0.0          1.0             6                6
# 3                 0.0          2.0            12                6
# 4                 0.0          7.0            42                6
#
#    medianamnt_loans90  payback30  payback90  pcircle      pdate
# 0                 0.0  29.000000  29.000000        0  7/20/2016
# 1                 0.0   0.000000   0.000000        0  8/10/2016
# 2                 0.0   0.000000   0.000000        0  8/19/2016
# 3                 0.0   0.000000   0.000000        0   6/6/2016
# 4                 0.0   2.333333   2.333333        0  6/22/2016

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209593 entries, 0 to 209592
# Data columns (total 36 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   label                 209593 non-null  int64
#  1   msisdn                209593 non-null  float64
#  2   aon                   209593 non-null  float64
#  3   daily_decr30          209593 non-null  float64
#  4   daily_decr90          209593 non-null  float64
#  5   rental30              209593 non-null  float64
#  6   rental90              209593 non-null  float64
#  7   last_rech_date_ma     209593 non-null  float64
#  8   last_rech_date_da     209593 non-null  float64
#  9   last_rech_amt_ma      209593 non-null  int64
#  10  cnt_ma_rech30         209593 non-null  int64
#  11  fr_ma_rech30          209593 non-null  float64
#  12  sumamnt_ma_rech30     209593 non-null  float64
#  13  medianamnt_ma_rech30  209593 non-null  float64
#  14  medianmarechprebal30  209593 non-null  float64
#  15  cnt_ma_rech90         209593 non-null  int64
#  16  fr_ma_rech90          209593 non-null  int64
#  17  sumamnt_ma_rech90     209593 non-null  int64
#  18  medianamnt_ma_rech90  209593 non-null  float64
#  19  medianmarechprebal90  209593 non-null  float64
#  20  cnt_da_rech30         209593 non-null  float64
#  21  fr_da_rech30          209593 non-null  float64
#  22  cnt_da_rech90         209593 non-null  int64
#  23  fr_da_rech90          209593 non-null  int64
#  24  cnt_loans30           209593 non-null  int64
#  25  amnt_loans30          209593 non-null  int64
#  26  maxamnt_loans30       209593 non-null  float64
#  27  medianamnt_loans30    209593 non-null  float64
#  28  cnt_loans90           209593 non-null  float64
#  29  amnt_loans90          209593 non-null  int64
#  30  maxamnt_loans90       209593 non-null  int64
#  31  medianamnt_loans90    209593 non-null  float64
#  32  payback30             209593 non-null  float64
#  33  payback90             209593 non-null  float64
#  34  pcircle               209593 non-null  int32
#  35  pdate                 209593 non-null  object
# dtypes: float64(22), int32(1), int64(12), object(1)
# memory usage: 56.8+ MB

# %%
# check the discription of dataset
df.describe()
# Out:
#                label         msisdn            aon   daily_decr30  \
# count  209593.000000  209593.000000  209593.000000  209593.000000
# mean        0.875177   49748.715930    8112.343445    5381.402289
# std         0.330519   28905.713576   75696.082531    9220.623400
# min         0.000000       4.000000     -48.000000     -93.012667
# 25%         1.000000   24659.000000     246.000000      42.440000
# 50%         1.000000   49056.000000     527.000000    1469.175667
# 75%         1.000000   75033.000000     982.000000    7244.000000
# max         1.000000   99998.000000  999860.755200  265926.000000
#
#         daily_decr90       rental30       rental90  last_rech_date_ma  \
# count  209593.000000  209593.000000  209593.000000       209593.00000
# mean     6082.515068    2692.581910    3483.406534         3755.84780
# std     10918.812767    4308.586781    5770.461279        53905.89223
# min       -93.012667  -23737.140000  -24720.580000          -29.00000
# 25%        42.692000     280.420000     300.260000            1.00000
# 50%      1500.000000    1083.570000    1334.000000            3.00000
# 75%      7802.790000    3356.940000    4201.790000            7.00000
# max    320630.000000  198926.110000  200148.110000       998650.37770
#
#        last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30   fr_ma_rech30  \
# count      209593.000000     209593.000000  209593.000000  209593.000000
# mean         3712.202921       2064.452797       3.978057    3737.355121
# std         53374.833430       2370.786034       4.256090   53643.625172
# min           -29.000000          0.000000       0.000000       0.000000
# 25%             0.000000        770.000000       1.000000       0.000000
# 50%             0.000000       1539.000000       3.000000       2.000000
# 75%             0.000000       2309.000000       5.000000       6.000000
# max        999171.809400      55000.000000     203.000000  999606.368100
#
#        sumamnt_ma_rech30  medianamnt_ma_rech30  medianmarechprebal30  \
# count      209593.000000         209593.000000         209593.000000
# mean         7704.501157           1812.817952           3851.927942
# std         10139.621714           2070.864620          54006.374433
# min             0.000000              0.000000           -200.000000
# 25%          1540.000000            770.000000             11.000000
# 50%          4628.000000           1539.000000             33.900000
# 75%         10010.000000           1924.000000             83.000000
# max        810096.000000          55000.000000         999479.419300
#
#        cnt_ma_rech90   fr_ma_rech90  sumamnt_ma_rech90  medianamnt_ma_rech90  \
# count   209593.00000  209593.000000      209593.000000         209593.000000
# mean         6.31543       7.716780       12396.218352           1864.595821
# std          7.19347      12.590251       16857.793882           2081.680664
# min          0.00000       0.000000           0.000000              0.000000
# 25%          2.00000       0.000000        2317.000000            773.000000
# 50%          4.00000       2.000000        7226.000000           1539.000000
# 75%          8.00000       8.000000       16000.000000           1924.000000
# max        336.00000      88.000000      953036.000000          55000.000000
#
#        medianmarechprebal90  cnt_da_rech30   fr_da_rech30  cnt_da_rech90  \
# count         209593.000000  209593.000000  209593.000000  209593.000000
# mean              92.025541     262.578110    3749.494447       0.041495
# std              369.215658    4183.897978   53885.414979       0.397556
# min             -200.000000       0.000000       0.000000       0.000000
# 25%               14.600000       0.000000       0.000000       0.000000
# 50%               36.000000       0.000000       0.000000       0.000000
# 75%               79.310000       0.000000       0.000000       0.000000
# max            41456.500000   99914.441420  999809.240100      38.000000
#
#         fr_da_rech90    cnt_loans30   amnt_loans30  maxamnt_loans30  \
# count  209593.000000  209593.000000  209593.000000    209593.000000
# mean        0.045712       2.758981      17.952021       274.658747
# std         0.951386       2.554502      17.379741      4245.264648
# min         0.000000       0.000000       0.000000         0.000000
# 25%         0.000000       1.000000       6.000000         6.000000
# 50%         0.000000       2.000000      12.000000         6.000000
# 75%         0.000000       4.000000      24.000000         6.000000
# max        64.000000      50.000000     306.000000     99864.560860
#
#        medianamnt_loans30    cnt_loans90   amnt_loans90  maxamnt_loans90  \
# count       209593.000000  209593.000000  209593.000000    209593.000000
# mean             0.054029      18.520919      23.645398         6.703134
# std              0.218039     224.797423      26.469861         2.103864
# min              0.000000       0.000000       0.000000         0.000000
# 25%              0.000000       1.000000       6.000000         6.000000
# 50%              0.000000       2.000000      12.000000         6.000000
# 75%              0.000000       5.000000      30.000000         6.000000
# max              3.000000    4997.517944     438.000000        12.000000
#
#        medianamnt_loans90      payback30      payback90   pcircle
# count       209593.000000  209593.000000  209593.000000  209593.0
# mean             0.046077       3.398826       4.321485       0.0
# std              0.200692       8.813729      10.308108       0.0
# min              0.000000       0.000000       0.000000       0.0
# 25%              0.000000       0.000000       0.000000       0.0
# 50%              0.000000       0.000000       1.666667       0.0
# 75%              0.000000       3.750000       4.500000       0.0
# max              3.000000     171.500000     171.500000       0.0

# %% [markdown]
# # EDA(EXPLORATRY DATA ANALYSIS)

# %%
# print the dataset
df.columns
# Out:
# Index(['label', 'msisdn', 'aon', 'daily_decr30', 'daily_decr90', 'rental30',
#        'rental90', 'last_rech_date_ma', 'last_rech_date_da',
#        'last_rech_amt_ma', 'cnt_ma_rech30', 'fr_ma_rech30',
#        'sumamnt_ma_rech30', 'medianamnt_ma_rech30', 'medianmarechprebal30',
#        'cnt_ma_rech90', 'fr_ma_rech90', 'sumamnt_ma_rech90',
#        'medianamnt_ma_rech90', 'medianmarechprebal90', 'cnt_da_rech30',
#        'fr_da_rech30', 'cnt_da_rech90', 'fr_da_rech90', 'cnt_loans30',
#        'amnt_loans30', 'maxamnt_loans30', 'medianamnt_loans30', 'cnt_loans90',
#        'amnt_loans90', 'maxamnt_loans90', 'medianamnt_loans90', 'payback30',
#        'payback90', 'pcircle', 'pdate'],
#       dtype='object')

# %%
df=df.drop(columns=["pdate"],axis=1)

# %%
# check the shape of dataset
df.shape
# Out:
# (209593, 35)

# %%
df.head()
# Out:
#    label   msisdn    aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0      0  21408.0  272.0   3055.050000   3065.150000    220.13    260.13
# 1      1  76462.0  712.0  12122.000000  12124.750000   3691.26   3691.26
# 2      1  17943.0  535.0   1398.000000   1398.000000    900.13    900.13
# 3      1  55773.0  241.0     21.228000     21.228000    159.42    159.42
# 4      1   3813.0  947.0    150.619333    150.619333   1098.90   1098.90
#
#    last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  \
# 0                2.0                0.0              1539              2
# 1               20.0                0.0              5787              1
# 2                3.0                0.0              1539              1
# 3               41.0                0.0               947              0
# 4                4.0                0.0              2309              7
#
#    fr_ma_rech30  sumamnt_ma_rech30  medianamnt_ma_rech30  \
# 0          21.0             3078.0                1539.0
# 1           0.0             5787.0                5787.0
# 2           0.0             1539.0                1539.0
# 3           0.0                0.0                   0.0
# 4           2.0            20029.0                2309.0
#
#    medianmarechprebal30  cnt_ma_rech90  fr_ma_rech90  sumamnt_ma_rech90  \
# 0                  7.50              2            21               3078
# 1                 61.04              1             0               5787
# 2                 66.32              1             0               1539
# 3                  0.00              1             0                947
# 4                 29.00              8             2              23496
#
#    medianamnt_ma_rech90  medianmarechprebal90  cnt_da_rech30  fr_da_rech30  \
# 0                1539.0                  7.50            0.0           0.0
# 1                5787.0                 61.04            0.0           0.0
# 2                1539.0                 66.32            0.0           0.0
# 3                 947.0                  2.50            0.0           0.0
# 4                2888.0                 35.00            0.0           0.0
#
#    cnt_da_rech90  fr_da_rech90  cnt_loans30  amnt_loans30  maxamnt_loans30  \
# 0              0             0            2            12              6.0
# 1              0             0            1            12             12.0
# 2              0             0            1             6              6.0
# 3              0             0            2            12              6.0
# 4              0             0            7            42              6.0
#
#    medianamnt_loans30  cnt_loans90  amnt_loans90  maxamnt_loans90  \
# 0                 0.0          2.0            12                6
# 1                 0.0          1.0            12               12
# 2                 0.0          1.0             6                6
# 3                 0.0          2.0            12                6
# 4                 0.0          7.0            42                6
#
#    medianamnt_loans90  payback30  payback90  pcircle
# 0                 0.0  29.000000  29.000000        0
# 1                 0.0   0.000000   0.000000        0
# 2                 0.0   0.000000   0.000000        0
# 3                 0.0   0.000000   0.000000        0
# 4                 0.0   2.333333   2.333333        0

# %%
# worning ignore
import warnings
warnings.filterwarnings("ignore")

# %%
# distribution plot
plt.figure(figsize=(20,20))
graph=1
for num in df[:35]:
    plt.subplot(6,6,graph)
    sns.distplot(df[num])
    plt.xlabel(num,fontsize=12)
    graph+=1
plt.show()
# check the univarient

# %%
# drop pcircle column
df=df.drop(columns=["pcircle"],axis=1)
# check the slewness 
df.skew()
# Out:
# label                   -2.270254
# msisdn                   0.018124
# aon                     10.392949
# daily_decr30             3.946230
# daily_decr90             4.252565
# rental30                 4.521929
# rental90                 4.437681
# last_rech_date_ma       14.790974
# last_rech_date_da       14.814857
# last_rech_amt_ma         3.781149
# cnt_ma_rech30            3.283842
# fr_ma_rech30            14.772833
# sumamnt_ma_rech30        6.386787
# medianamnt_ma_rech30     3.512324
# medianmarechprebal30    14.779875
# cnt_ma_rech90            3.425254
# fr_ma_rech90             2.285423
# sumamnt_ma_rech90        4.897950
# medianamnt_ma_rech90     3.752706
# medianmarechprebal90    44.880503
# cnt_da_rech30           17.818364
# fr_da_rech30            14.776430
# cnt_da_rech90           27.267278
# fr_da_rech90            28.988083
# cnt_loans30              2.713421
# amnt_loans30             2.975719
# maxamnt_loans30         17.658052
# medianamnt_loans30       4.551043
# cnt_loans90             16.594408
# amnt_loans90             3.150006
# maxamnt_loans90          1.678304
# medianamnt_loans90       4.895720
# payback30                8.310695
# payback90                6.899951
# dtype: float64

# %% [markdown]
# # it is highly skewed multitiple feature

# %%
# List of highly skewed features
skewed_features = [
    
    "daily_decr30", 
    "daily_decr90",
    "rental30",
    "rental90",
    "last_rech_amt_ma",
    "cnt_ma_rech30",
    "sumamnt_ma_rech30", 
    "cnt_ma_rech90", 
    "sumamnt_ma_rech90",
    "cnt_loans30",
    "amnt_loans30", 
    "maxamnt_loans30", 
    "cnt_loans90",
    "fr_da_rech30",
    "amnt_loans90", 
    "maxamnt_loans90", 
    "payback30", 
    "payback90",
    "last_rech_date_ma",
    "last_rech_date_da",
    "cnt_da_rech30",
    "cnt_da_rech90",
    "cnt_da_rech90",
    "fr_ma_rech30",
    "fr_da_rech30"

]

# %%
df[skewed_features].describe()
# Out:
#         daily_decr30   daily_decr90       rental30       rental90  \
# count  209593.000000  209593.000000  209593.000000  209593.000000
# mean     5381.402289    6082.515068    2692.581910    3483.406534
# std      9220.623400   10918.812767    4308.586781    5770.461279
# min       -93.012667     -93.012667  -23737.140000  -24720.580000
# 25%        42.440000      42.692000     280.420000     300.260000
# 50%      1469.175667    1500.000000    1083.570000    1334.000000
# 75%      7244.000000    7802.790000    3356.940000    4201.790000
# max    265926.000000  320630.000000  198926.110000  200148.110000
#
#        last_rech_amt_ma  cnt_ma_rech30  sumamnt_ma_rech30  cnt_ma_rech90  \
# count     209593.000000  209593.000000      209593.000000   209593.00000
# mean        2064.452797       3.978057        7704.501157        6.31543
# std         2370.786034       4.256090       10139.621714        7.19347
# min            0.000000       0.000000           0.000000        0.00000
# 25%          770.000000       1.000000        1540.000000        2.00000
# 50%         1539.000000       3.000000        4628.000000        4.00000
# 75%         2309.000000       5.000000       10010.000000        8.00000
# max        55000.000000     203.000000      810096.000000      336.00000
#
#        sumamnt_ma_rech90    cnt_loans30   amnt_loans30  maxamnt_loans30  \
# count      209593.000000  209593.000000  209593.000000    209593.000000
# mean        12396.218352       2.758981      17.952021       274.658747
# std         16857.793882       2.554502      17.379741      4245.264648
# min             0.000000       0.000000       0.000000         0.000000
# 25%          2317.000000       1.000000       6.000000         6.000000
# 50%          7226.000000       2.000000      12.000000         6.000000
# 75%         16000.000000       4.000000      24.000000         6.000000
# max        953036.000000      50.000000     306.000000     99864.560860
#
#          cnt_loans90   fr_da_rech30   amnt_loans90  maxamnt_loans90  \
# count  209593.000000  209593.000000  209593.000000    209593.000000
# mean       18.520919    3749.494447      23.645398         6.703134
# std       224.797423   53885.414979      26.469861         2.103864
# min         0.000000       0.000000       0.000000         0.000000
# 25%         1.000000       0.000000       6.000000         6.000000
# 50%         2.000000       0.000000      12.000000         6.000000
# 75%         5.000000       0.000000      30.000000         6.000000
# max      4997.517944  999809.240100     438.000000        12.000000
#
#            payback30      payback90  last_rech_date_ma  last_rech_date_da  \
# count  209593.000000  209593.000000       209593.00000      209593.000000
# mean        3.398826       4.321485         3755.84780        3712.202921
# std         8.813729      10.308108        53905.89223       53374.833430
# min         0.000000       0.000000          -29.00000         -29.000000
# 25%         0.000000       0.000000            1.00000           0.000000
# 50%         0.000000       1.666667            3.00000           0.000000
# 75%         3.750000       4.500000            7.00000           0.000000
# max       171.500000     171.500000       998650.37770      999171.809400
#
#        cnt_da_rech30  cnt_da_rech90  cnt_da_rech90   fr_ma_rech30  \
# count  209593.000000  209593.000000  209593.000000  209593.000000
# mean      262.578110       0.041495       0.041495    3737.355121
# std      4183.897978       0.397556       0.397556   53643.625172
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         0.000000       0.000000       0.000000       2.000000
# 75%         0.000000       0.000000       0.000000       6.000000
# max     99914.441420      38.000000      38.000000  999606.368100
#
#         fr_da_rech30
# count  209593.000000
# mean     3749.494447
# std     53885.414979
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max    999809.240100

# %%
df.isnull().sum()
# Out:
# label                   0
# msisdn                  0
# aon                     0
# daily_decr30            0
# daily_decr90            0
# rental30                0
# rental90                0
# last_rech_date_ma       0
# last_rech_date_da       0
# last_rech_amt_ma        0
# cnt_ma_rech30           0
# fr_ma_rech30            0
# sumamnt_ma_rech30       0
# medianamnt_ma_rech30    0
# medianmarechprebal30    0
# cnt_ma_rech90           0
# fr_ma_rech90            0
# sumamnt_ma_rech90       0
# medianamnt_ma_rech90    0
# medianmarechprebal90    0
# cnt_da_rech30           0
# fr_da_rech30            0
# cnt_da_rech90           0
# fr_da_rech90            0
# cnt_loans30             0
# amnt_loans30            0
# maxamnt_loans30         0
# medianamnt_loans30      0
# cnt_loans90             0
# amnt_loans90            0
# maxamnt_loans90         0
# medianamnt_loans90      0
# payback30               0
# payback90               0
# dtype: int64

# %%
# after the check of distribution
plt.figure(figsize=(20,20))
graph=1
for num in df[:35]:
    plt.subplot(6,6,graph)
    sns.distplot(df[num])
    plt.xlabel(num,fontsize=12)
    graph+=1
plt.show()

# %%
#sns.pairplot(df[:5])  # Only first 5 columns to avoid heavy computation
#plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15, 8))
df.mean().sort_values().plot(kind="bar", color="skyblue", edgecolor="black")
plt.title("Mean Values of All Features", fontsize=14)
plt.xlabel("Features", fontsize=12)
plt.ylabel("Mean Value", fontsize=12)
plt.xticks(rotation=90)
plt.show()

# %%
abs(df.corr())
# Out:
#                          label    msisdn       aon  daily_decr30  \
# label                 1.000000  0.001945  0.003785      0.222352
# msisdn                0.001945  1.000000  0.000555      0.002552
# aon                   0.003785  0.000555  1.000000      0.001110
# daily_decr30          0.222352  0.002552  0.001110      1.000000
# daily_decr90          0.224490  0.002527  0.001246      0.998186
# rental30              0.065101  0.001006  0.001264      0.480765
# rental90              0.083945  0.000494  0.001244      0.523836
# last_rech_date_ma     0.022318  0.001344  0.001609      0.011601
# last_rech_date_da     0.005964  0.002291  0.002230      0.012393
# last_rech_amt_ma      0.317340  0.000595  0.002083      0.340274
# cnt_ma_rech30         0.328192  0.000488  0.003216      0.455963
# fr_ma_rech30          0.140801  0.002255  0.000423      0.148055
# sumamnt_ma_rech30     0.368225  0.000931  0.000114      0.430203
# medianamnt_ma_rech30  0.141490  0.000669  0.004306      0.245444
# medianmarechprebal30  0.004829  0.000253  0.003930      0.000358
# cnt_ma_rech90         0.347315  0.001597  0.002298      0.604661
# fr_ma_rech90          0.084385  0.004409  0.004401      0.018678
# sumamnt_ma_rech90     0.380146  0.000992  0.000985      0.498880
# medianamnt_ma_rech90  0.120855  0.000621  0.004909      0.216977
# medianmarechprebal90  0.039300  0.000574  0.000859      0.022977
# cnt_da_rech30         0.003753  0.001737  0.002306      0.007360
# fr_da_rech30          0.000741  0.000088  0.002015      0.006284
# cnt_da_rech90         0.011206  0.003566  0.000195      0.064643
# fr_da_rech90          0.005418  0.002249  0.005395      0.031881
# cnt_loans30           0.231972  0.002591  0.002534      0.342753
# amnt_loans30          0.239176  0.003616  0.002757      0.390524
# maxamnt_loans30       0.015435  0.001312  0.003839      0.089782
# medianamnt_loans30    0.044589  0.000988  0.004664      0.006395
# cnt_loans90           0.193187  0.002171  0.000972      0.383625
# amnt_loans90          0.267562  0.002350  0.001975      0.535527
# maxamnt_loans90       0.057336  0.004626  0.001786      0.292090
# medianamnt_loans90    0.035747  0.001213  0.002771      0.030051
# payback30             0.173381  0.004994  0.000463      0.242857
# payback90             0.180553  0.004008  0.001787      0.320776
#
#                       daily_decr90  rental30  rental90  last_rech_date_ma  \
# label                     0.224490  0.065101  0.083945           0.022318
# msisdn                    0.002527  0.001006  0.000494           0.001344
# aon                       0.001246  0.001264  0.001244           0.001609
# daily_decr30              0.998186  0.480765  0.523836           0.011601
# daily_decr90              1.000000  0.483139  0.532392           0.012810
# rental30                  0.483139  1.000000  0.962173           0.000034
# rental90                  0.532392  0.962173  1.000000           0.002682
# last_rech_date_ma         0.012810  0.000034  0.002682           1.000000
# last_rech_date_da         0.012353  0.005566  0.005590           0.002879
# last_rech_amt_ma          0.339749  0.168531  0.176794           0.075373
# cnt_ma_rech30             0.451063  0.270931  0.274610           0.071224
# fr_ma_rech30              0.147768  0.058062  0.063875           0.032546
# sumamnt_ma_rech30         0.425910  0.228811  0.232830           0.048566
# medianamnt_ma_rech30      0.242795  0.130776  0.124198           0.018245
# medianmarechprebal30      0.000481  0.001356  0.001090           0.005058
# cnt_ma_rech90             0.609019  0.345093  0.380746           0.034311
# fr_ma_rech90              0.019821  0.035331  0.038694           0.000626
# sumamnt_ma_rech90         0.500386  0.262819  0.282524           0.037776
# medianamnt_ma_rech90      0.216659  0.108980  0.104423           0.060862
# medianmarechprebal90      0.023065  0.022465  0.025128           0.019542
# cnt_da_rech30             0.007141  0.006123  0.004707           0.003607
# fr_da_rech30              0.005979  0.010776  0.008982           0.005356
# cnt_da_rech90             0.062974  0.056574  0.047390           0.003719
# fr_da_rech90              0.030705  0.050200  0.042351           0.000529
# cnt_loans30               0.336378  0.202795  0.197746           0.058343
# amnt_loans30              0.384847  0.233444  0.232898           0.058551
# maxamnt_loans30           0.088980  0.061786  0.063053           0.008626
# medianamnt_loans30        0.008813  0.018168  0.011213           0.009119
# cnt_loans90               0.385489  0.225990  0.247223           0.035480
# amnt_loans90              0.537521  0.312775  0.339885           0.046734
# maxamnt_loans90           0.292982  0.195341  0.209186           0.014925
# medianamnt_loans90        0.029441  0.038999  0.038289           0.009068
# payback30                 0.239681  0.154979  0.156274           0.048706
# payback90                 0.320794  0.189848  0.206351           0.031402
#
#                       last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  \
# label                          0.005964          0.317340       0.328192
# msisdn                         0.002291          0.000595       0.000488
# aon                            0.002230          0.002083       0.003216
# daily_decr30                   0.012393          0.340274       0.455963
# daily_decr90                   0.012353          0.339749       0.451063
# rental30                       0.005566          0.168531       0.270931
# rental90                       0.005590          0.176794       0.274610
# last_rech_date_ma              0.002879          0.075373       0.071224
# last_rech_date_da              1.000000          0.006302       0.003970
# last_rech_amt_ma               0.006302          1.000000       0.446608
# cnt_ma_rech30                  0.003970          0.446608       1.000000
# fr_ma_rech30                   0.003419          0.215011       0.181671
# sumamnt_ma_rech30              0.005489          0.799340       0.757412
# medianamnt_ma_rech30           0.003415          0.501259       0.067409
# medianmarechprebal30           0.001580          0.003062       0.000415
# cnt_ma_rech90                  0.005331          0.485853       0.919158
# fr_ma_rech90                   0.002039          0.210613       0.080150
# sumamnt_ma_rech90              0.007238          0.922433       0.694106
# medianamnt_ma_rech90           0.002917          0.510740       0.002912
# medianmarechprebal90           0.006623          0.107538       0.010195
# cnt_da_rech30                  0.001877          0.001166       0.004913
# fr_da_rech30                   0.003440          0.000678       0.001310
# cnt_da_rech90                  0.113831          0.023999       0.014341
# fr_da_rech90                   0.023120          0.008355       0.006803
# cnt_loans30                    0.000486          0.237536       0.745037
# amnt_loans30                   0.001840          0.260542       0.722423
# maxamnt_loans30                0.001305          0.028575       0.065565
# medianamnt_loans30             0.000876          0.011315       0.066292
# cnt_loans90                    0.000066          0.199398       0.544881
# amnt_loans90                   0.001697          0.294007       0.712373
# maxamnt_loans90                0.004712          0.097152       0.176611
# medianamnt_loans90             0.001911          0.003270       0.076242
# payback30                      0.000630          0.213300       0.379929
# payback90                      0.004904          0.243077       0.329898
#
#                       fr_ma_rech30  sumamnt_ma_rech30  medianamnt_ma_rech30  \
# label                     0.140801           0.368225              0.141490
# msisdn                    0.002255           0.000931              0.000669
# aon                       0.000423           0.000114              0.004306
# daily_decr30              0.148055           0.430203              0.245444
# daily_decr90              0.147768           0.425910              0.242795
# rental30                  0.058062           0.228811              0.130776
# rental90                  0.063875           0.232830              0.124198
# last_rech_date_ma         0.032546           0.048566              0.018245
# last_rech_date_da         0.003419           0.005489              0.003415
# last_rech_amt_ma          0.215011           0.799340              0.501259
# cnt_ma_rech30             0.181671           0.757412              0.067409
# fr_ma_rech30              1.000000           0.285285              0.126027
# sumamnt_ma_rech30         0.285285           1.000000              0.456229
# medianamnt_ma_rech30      0.126027           0.456229              1.000000
# medianmarechprebal30      0.001388           0.003087              0.000737
# cnt_ma_rech90             0.190312           0.709790              0.091223
# fr_ma_rech90              0.189604           0.153815              0.149655
# sumamnt_ma_rech90         0.258936           0.888556              0.421052
# medianamnt_ma_rech90      0.085321           0.318473              0.864846
# medianmarechprebal90      0.011942           0.056368              0.156028
# cnt_da_rech30             0.004551           0.005312              0.002173
# fr_da_rech30              0.000120           0.002311              0.000775
# cnt_da_rech90             0.010825           0.023250              0.021175
# fr_da_rech90              0.000237           0.007642              0.013734
# cnt_loans30               0.113114           0.475869              0.014367
# amnt_loans30              0.136178           0.493394              0.032136
# maxamnt_loans30           0.016604           0.055570              0.042675
# medianamnt_loans30        0.001048           0.017844              0.032477
# cnt_loans90               0.104283           0.366520              0.011652
# amnt_loans90              0.155848           0.511725              0.054578
# maxamnt_loans90           0.044565           0.158102              0.127853
# medianamnt_loans90        0.012632           0.034028              0.022692
# payback30                 0.227534           0.345032              0.025494
# payback90                 0.209288           0.343445              0.008066
#
#                       medianmarechprebal30  cnt_ma_rech90  fr_ma_rech90  \
# label                             0.004829       0.347315      0.084385
# msisdn                            0.000253       0.001597      0.004409
# aon                               0.003930       0.002298      0.004401
# daily_decr30                      0.000358       0.604661      0.018678
# daily_decr90                      0.000481       0.609019      0.019821
# rental30                          0.001356       0.345093      0.035331
# rental90                          0.001090       0.380746      0.038694
# last_rech_date_ma                 0.005058       0.034311      0.000626
# last_rech_date_da                 0.001580       0.005331      0.002039
# last_rech_amt_ma                  0.003062       0.485853      0.210613
# cnt_ma_rech30                     0.000415       0.919158      0.080150
# fr_ma_rech30                      0.001388       0.190312      0.189604
# sumamnt_ma_rech30                 0.003087       0.709790      0.153815
# medianamnt_ma_rech30              0.000737       0.091223      0.149655
# medianmarechprebal30              1.000000       0.000302      0.000902
# cnt_ma_rech90                     0.000302       1.000000      0.044281
# fr_ma_rech90                      0.000902       0.044281      1.000000
# sumamnt_ma_rech90                 0.002524       0.754617      0.166508
# medianamnt_ma_rech90              0.001459       0.035799      0.138503
# medianmarechprebal90              0.000529       0.021138      0.004347
# cnt_da_rech30                     0.003008       0.004547      0.000514
# fr_da_rech30                      0.000148       0.001072      0.001579
# cnt_da_rech90                     0.002639       0.012210      0.004521
# fr_da_rech90                      0.001412       0.005763      0.003822
# cnt_loans30                       0.000258       0.694247      0.093605
# amnt_loans30                      0.000649       0.687500      0.080639
# maxamnt_loans30                   0.001867       0.072926      0.015617
# medianamnt_loans30                0.002289       0.052885      0.020626
# cnt_loans90                       0.000744       0.584367      0.074970
# amnt_loans90                      0.000279       0.764940      0.079201
# maxamnt_loans90                   0.001491       0.217808      0.040697
# medianamnt_loans90                0.001927       0.079531      0.016964
# payback30                         0.001909       0.349136      0.050565
# payback90                         0.002587       0.341966      0.099130
#
#                       sumamnt_ma_rech90  medianamnt_ma_rech90  \
# label                          0.380146              0.120855
# msisdn                         0.000992              0.000621
# aon                            0.000985              0.004909
# daily_decr30                   0.498880              0.216977
# daily_decr90                   0.500386              0.216659
# rental30                       0.262819              0.108980
# rental90                       0.282524              0.104423
# last_rech_date_ma              0.037776              0.060862
# last_rech_date_da              0.007238              0.002917
# last_rech_amt_ma               0.922433              0.510740
# cnt_ma_rech30                  0.694106              0.002912
# fr_ma_rech30                   0.258936              0.085321
# sumamnt_ma_rech30              0.888556              0.318473
# medianamnt_ma_rech30           0.421052              0.864846
# medianmarechprebal30           0.002524              0.001459
# cnt_ma_rech90                  0.754617              0.035799
# fr_ma_rech90                   0.166508              0.138503
# sumamnt_ma_rech90              1.000000              0.417630
# medianamnt_ma_rech90           0.417630              1.000000
# medianmarechprebal90           0.100071              0.209096
# cnt_da_rech30                  0.003578              0.000426
# fr_da_rech30                   0.001323              0.000810
# cnt_da_rech90                  0.028339              0.023482
# fr_da_rech90                   0.012314              0.019677
# cnt_loans30                    0.444114              0.056016
# amnt_loans30                   0.461616              0.016174
# maxamnt_loans30                0.050047              0.030315
# medianamnt_loans30             0.010490              0.036475
# cnt_loans90                    0.372990              0.025377
# amnt_loans90                   0.516830              0.001104
# maxamnt_loans90                0.158534              0.098210
# medianamnt_loans90             0.032460              0.031696
# payback30                      0.305786              0.064679
# payback90                      0.328828              0.036733
#
#                       medianmarechprebal90  cnt_da_rech30  fr_da_rech30  \
# label                             0.039300       0.003753      0.000741
# msisdn                            0.000574       0.001737      0.000088
# aon                               0.000859       0.002306      0.002015
# daily_decr30                      0.022977       0.007360      0.006284
# daily_decr90                      0.023065       0.007141      0.005979
# rental30                          0.022465       0.006123      0.010776
# rental90                          0.025128       0.004707      0.008982
# last_rech_date_ma                 0.019542       0.003607      0.005356
# last_rech_date_da                 0.006623       0.001877      0.003440
# last_rech_amt_ma                  0.107538       0.001166      0.000678
# cnt_ma_rech30                     0.010195       0.004913      0.001310
# fr_ma_rech30                      0.011942       0.004551      0.000120
# sumamnt_ma_rech30                 0.056368       0.005312      0.002311
# medianamnt_ma_rech30              0.156028       0.002173      0.000775
# medianmarechprebal30              0.000529       0.003008      0.000148
# cnt_ma_rech90                     0.021138       0.004547      0.001072
# fr_ma_rech90                      0.004347       0.000514      0.001579
# sumamnt_ma_rech90                 0.100071       0.003578      0.001323
# medianamnt_ma_rech90              0.209096       0.000426      0.000810
# medianmarechprebal90              1.000000       0.001388      0.001067
# cnt_da_rech30                     0.001388       1.000000      0.014546
# fr_da_rech30                      0.001067       0.014546      1.000000
# cnt_da_rech90                     0.014595       0.083154      0.100763
# fr_da_rech90                      0.008492       0.038301      0.089312
# cnt_loans30                       0.049363       0.003745      0.001335
# amnt_loans30                      0.039123       0.003711      0.002390
# maxamnt_loans30                   0.005436       0.001068      0.002438
# medianamnt_loans30                0.030534       0.000391      0.002411
# cnt_loans90                       0.038954       0.002558      0.001766
# amnt_loans90                      0.042666       0.005865      0.003375
# maxamnt_loans90                   0.013377       0.001511      0.003010
# medianamnt_loans90                0.032453       0.002191      0.002407
# payback30                         0.059070       0.005321      0.005765
# payback90                         0.057802       0.005384      0.004220
#
#                       cnt_da_rech90  fr_da_rech90  cnt_loans30  amnt_loans30  \
# label                      0.011206      0.005418     0.231972      0.239176
# msisdn                     0.003566      0.002249     0.002591      0.003616
# aon                        0.000195      0.005395     0.002534      0.002757
# daily_decr30               0.064643      0.031881     0.342753      0.390524
# daily_decr90               0.062974      0.030705     0.336378      0.384847
# rental30                   0.056574      0.050200     0.202795      0.233444
# rental90                   0.047390      0.042351     0.197746      0.232898
# last_rech_date_ma          0.003719      0.000529     0.058343      0.058551
# last_rech_date_da          0.113831      0.023120     0.000486      0.001840
# last_rech_amt_ma           0.023999      0.008355     0.237536      0.260542
# cnt_ma_rech30              0.014341      0.006803     0.745037      0.722423
# fr_ma_rech30               0.010825      0.000237     0.113114      0.136178
# sumamnt_ma_rech30          0.023250      0.007642     0.475869      0.493394
# medianamnt_ma_rech30       0.021175      0.013734     0.014367      0.032136
# medianmarechprebal30       0.002639      0.001412     0.000258      0.000649
# cnt_ma_rech90              0.012210      0.005763     0.694247      0.687500
# fr_ma_rech90               0.004521      0.003822     0.093605      0.080639
# sumamnt_ma_rech90          0.028339      0.012314     0.444114      0.461616
# medianamnt_ma_rech90       0.023482      0.019677     0.056016      0.016174
# medianmarechprebal90       0.014595      0.008492     0.049363      0.039123
# cnt_da_rech30              0.083154      0.038301     0.003745      0.003711
# fr_da_rech30               0.100763      0.089312     0.001335      0.002390
# cnt_da_rech90              1.000000      0.420215     0.020386      0.028250
# fr_da_rech90               0.420215      1.000000     0.010673      0.015006
# cnt_loans30                0.020386      0.010673     1.000000      0.960643
# amnt_loans30               0.028250      0.015006     0.960643      1.000000
# maxamnt_loans30            0.011680      0.006575     0.098536      0.187991
# medianamnt_loans30         0.001584      0.002234     0.098272      0.070492
# cnt_loans90                0.016932      0.008594     0.691688      0.671453
# amnt_loans90               0.029527      0.014549     0.893925      0.921708
# maxamnt_loans90            0.037353      0.019847     0.214663      0.429507
# medianamnt_loans90         0.001730      0.000949     0.107905      0.088862
# payback30                  0.021744      0.003257     0.463647      0.478556
# payback90                  0.040373      0.005212     0.387058      0.405663
#
#                       maxamnt_loans30  medianamnt_loans30  cnt_loans90  \
# label                        0.015435            0.044589     0.193187
# msisdn                       0.001312            0.000988     0.002171
# aon                          0.003839            0.004664     0.000972
# daily_decr30                 0.089782            0.006395     0.383625
# daily_decr90                 0.088980            0.008813     0.385489
# rental30                     0.061786            0.018168     0.225990
# rental90                     0.063053            0.011213     0.247223
# last_rech_date_ma            0.008626            0.009119     0.035480
# last_rech_date_da            0.001305            0.000876     0.000066
# last_rech_amt_ma             0.028575            0.011315     0.199398
# cnt_ma_rech30                0.065565            0.066292     0.544881
# fr_ma_rech30                 0.016604            0.001048     0.104283
# sumamnt_ma_rech30            0.055570            0.017844     0.366520
# medianamnt_ma_rech30         0.042675            0.032477     0.011652
# medianmarechprebal30         0.001867            0.002289     0.000744
# cnt_ma_rech90                0.072926            0.052885     0.584367
# fr_ma_rech90                 0.015617            0.020626     0.074970
# sumamnt_ma_rech90            0.050047            0.010490     0.372990
# medianamnt_ma_rech90         0.030315            0.036475     0.025377
# medianmarechprebal90         0.005436            0.030534     0.038954
# cnt_da_rech30                0.001068            0.000391     0.002558
# fr_da_rech30                 0.002438            0.002411     0.001766
# cnt_da_rech90                0.011680            0.001584     0.016932
# fr_da_rech90                 0.006575            0.002234     0.008594
# cnt_loans30                  0.098536            0.098272     0.691688
# amnt_loans30                 0.187991            0.070492     0.671453
# maxamnt_loans30              1.000000            0.028413     0.073512
# medianamnt_loans30           0.028413            1.000000     0.064504
# cnt_loans90                  0.073512            0.064504     1.000000
# amnt_loans90                 0.155063            0.064813     0.739821
# maxamnt_loans90              0.352143            0.057267     0.194153
# medianamnt_loans90           0.018494            0.911604     0.090913
# payback30                    0.038253            0.051522     0.352949
# payback90                    0.031409            0.033740     0.333478
#
#                       amnt_loans90  maxamnt_loans90  medianamnt_loans90  \
# label                     0.267562         0.057336            0.035747
# msisdn                    0.002350         0.004626            0.001213
# aon                       0.001975         0.001786            0.002771
# daily_decr30              0.535527         0.292090            0.030051
# daily_decr90              0.537521         0.292982            0.029441
# rental30                  0.312775         0.195341            0.038999
# rental90                  0.339885         0.209186            0.038289
# last_rech_date_ma         0.046734         0.014925            0.009068
# last_rech_date_da         0.001697         0.004712            0.001911
# last_rech_amt_ma          0.294007         0.097152            0.003270
# cnt_ma_rech30             0.712373         0.176611            0.076242
# fr_ma_rech30              0.155848         0.044565            0.012632
# sumamnt_ma_rech30         0.511725         0.158102            0.034028
# medianamnt_ma_rech30      0.054578         0.127853            0.022692
# medianmarechprebal30      0.000279         0.001491            0.001927
# cnt_ma_rech90             0.764940         0.217808            0.079531
# fr_ma_rech90              0.079201         0.040697            0.016964
# sumamnt_ma_rech90         0.516830         0.158534            0.032460
# medianamnt_ma_rech90      0.001104         0.098210            0.031696
# medianmarechprebal90      0.042666         0.013377            0.032453
# cnt_da_rech30             0.005865         0.001511            0.002191
# fr_da_rech30              0.003375         0.003010            0.002407
# cnt_da_rech90             0.029527         0.037353            0.001730
# fr_da_rech90              0.014549         0.019847            0.000949
# cnt_loans30               0.893925         0.214663            0.107905
# amnt_loans30              0.921708         0.429507            0.088862
# maxamnt_loans30           0.155063         0.352143            0.018494
# medianamnt_loans30        0.064813         0.057267            0.911604
# cnt_loans90               0.739821         0.194153            0.090913
# amnt_loans90              1.000000         0.423975            0.103810
# maxamnt_loans90           0.423975         1.000000            0.034821
# medianamnt_loans90        0.103810         0.034821            1.000000
# payback30                 0.487797         0.088471            0.072742
# payback90                 0.474642         0.107411            0.069683
#
#                       payback30  payback90
# label                  0.173381   0.180553
# msisdn                 0.004994   0.004008
# aon                    0.000463   0.001787
# daily_decr30           0.242857   0.320776
# daily_decr90           0.239681   0.320794
# rental30               0.154979   0.189848
# rental90               0.156274   0.206351
# last_rech_date_ma      0.048706   0.031402
# last_rech_date_da      0.000630   0.004904
# last_rech_amt_ma       0.213300   0.243077
# cnt_ma_rech30          0.379929   0.329898
# fr_ma_rech30           0.227534   0.209288
# sumamnt_ma_rech30      0.345032   0.343445
# medianamnt_ma_rech30   0.025494   0.008066
# medianmarechprebal30   0.001909   0.002587
# cnt_ma_rech90          0.349136   0.341966
# fr_ma_rech90           0.050565   0.099130
# sumamnt_ma_rech90      0.305786   0.328828
# medianamnt_ma_rech90   0.064679   0.036733
# medianmarechprebal90   0.059070   0.057802
# cnt_da_rech30          0.005321   0.005384
# fr_da_rech30           0.005765   0.004220
# cnt_da_rech90          0.021744   0.040373
# fr_da_rech90           0.003257   0.005212
# cnt_loans30            0.463647   0.387058
# amnt_loans30           0.478556   0.405663
# maxamnt_loans30        0.038253   0.031409
# medianamnt_loans30     0.051522   0.033740
# cnt_loans90            0.352949   0.333478
# amnt_loans90           0.487797   0.474642
# maxamnt_loans90        0.088471   0.107411
# medianamnt_loans90     0.072742   0.069683
# payback30              1.000000   0.844241
# payback90              0.844241   1.000000

# %%
# print the heatmap and chek the multicolinearity
plt.figure(figsize=(60,60))

sns.heatmap(abs(df.corr()),annot=True) # check the correelation
# Out:
# <Axes: >

# %%
df['label'].value_counts(normalize=True).plot(kind='bar')
# Out:
# <Axes: xlabel='label'>

# %% [markdown]
# \# IT IS  MULTICOLINEARITY Some  COLUMNS

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(20, 20))
graph = 1

# Select the first 35 columns
features = df.columns[:35]

for num in features:
    plt.subplot(6, 6, graph)
    sns.histplot(df[num], kde=True, bins=30, color="r"  )  # kde=True adds a smooth density curve
    plt.xlabel(num, fontsize=12)
    graph += 1

plt.tight_layout()  # Adjust layout to prevent overlapping
plt.show()

# %%
df.columns
# Out:
# Index(['label', 'msisdn', 'aon', 'daily_decr30', 'daily_decr90', 'rental30',
#        'rental90', 'last_rech_date_ma', 'last_rech_date_da',
#        'last_rech_amt_ma', 'cnt_ma_rech30', 'fr_ma_rech30',
#        'sumamnt_ma_rech30', 'medianamnt_ma_rech30', 'medianmarechprebal30',
#        'cnt_ma_rech90', 'fr_ma_rech90', 'sumamnt_ma_rech90',
#        'medianamnt_ma_rech90', 'medianmarechprebal90', 'cnt_da_rech30',
#        'fr_da_rech30', 'cnt_da_rech90', 'fr_da_rech90', 'cnt_loans30',
#        'amnt_loans30', 'maxamnt_loans30', 'medianamnt_loans30', 'cnt_loans90',
#        'amnt_loans90', 'maxamnt_loans90', 'medianamnt_loans90', 'payback30',
#        'payback90'],
#       dtype='object')

# %%
# check the shape
df.shape
# Out:
# (209593, 34)

# %%
df.drop("label",axis=1).corrwith(df["label"]).plot(kind="bar",grid=True,title="corr with label",figsize=(20,20)) # corr with label
# Out:
# <Axes: title={'center': 'corr with label'}>

# %% [markdown]
# # check the outlier

# %%
plt.figure(figsize=(40,40))
graph=1
for num in df[:34]:
    plt.subplot(6,6,graph)
    sns.boxplot(data=df[num],orient="v")
    plt.xlabel(num,fontsize=12)
    graph+=1
plt.show()

# %% [markdown]
# #  remoove outlier some  feature because it is remoove the more rows of the dataset

# %%
df.columns
# Out:
# Index(['label', 'msisdn', 'aon', 'daily_decr30', 'daily_decr90', 'rental30',
#        'rental90', 'last_rech_date_ma', 'last_rech_date_da',
#        'last_rech_amt_ma', 'cnt_ma_rech30', 'fr_ma_rech30',
#        'sumamnt_ma_rech30', 'medianamnt_ma_rech30', 'medianmarechprebal30',
#        'cnt_ma_rech90', 'fr_ma_rech90', 'sumamnt_ma_rech90',
#        'medianamnt_ma_rech90', 'medianmarechprebal90', 'cnt_da_rech30',
#        'fr_da_rech30', 'cnt_da_rech90', 'fr_da_rech90', 'cnt_loans30',
#        'amnt_loans30', 'maxamnt_loans30', 'medianamnt_loans30', 'cnt_loans90',
#        'amnt_loans90', 'maxamnt_loans90', 'medianamnt_loans90', 'payback30',
#        'payback90'],
#       dtype='object')

# %%
from scipy.stats.mstats import winsorize

#  Filter rows within 2nd and 98th percentiles
lower_bound = df["last_rech_date_ma"].quantile(0.02)
upper_bound = df["last_rech_date_ma"].quantile(0.98)
df = df[(df["last_rech_date_ma"] >= lower_bound) & (df["last_rech_date_ma"] <= upper_bound)]

#  Cap extreme values (Winsorization) on remaining data
df["last_rech_date_ma"] = winsorize(df["last_rech_date_ma"], limits=[0.01, 0.01])  # Cap at 1% from each side

df = df.reset_index(drop=True)
print(df.shape)
# Out:
# (204090, 34)

# %%
from scipy.stats.mstats import winsorize

#  Filter rows within 2nd and 98th percentiles
lower_bound = df["last_rech_date_da"].quantile(0.02)
upper_bound = df["last_rech_date_da"].quantile(0.98)
df = df[(df["last_rech_date_da"] >= lower_bound) & (df["last_rech_date_da"] <= upper_bound)]

#  Cap extreme values (Winsorization) on remaining data
df["last_rech_date_da"] = winsorize(df["last_rech_date_da"], limits=[0.01, 0.01])  # Cap at 1% from each side

df = df.reset_index(drop=True)
print(df.shape)
# Out:
# (200099, 34)

# %%
from scipy.stats.mstats import winsorize

#  Filter rows within 2nd and 98th percentiles
lower_bound = df["fr_da_rech90"].quantile(0.02)
upper_bound = df["fr_da_rech90"].quantile(0.98)
df = df[(df["fr_da_rech90"] >= lower_bound) & (df["fr_da_rech90"] <= upper_bound)]

#  Cap extreme values (Winsorization) on remaining data
df["fr_da_rech90"] = winsorize(df["fr_da_rech90"], limits=[0.01, 0.01])  # Cap at 1% from each side

df = df.reset_index(drop=True)
print(df.shape)
# Out:
# (199377, 34)

# %%
from scipy.stats.mstats import winsorize

#  Filter rows within 2nd and 98th percentiles
lower_bound = df["rental30"].quantile(0.02)
upper_bound = df["rental30"].quantile(0.98)
df = df[(df["rental30"] >= lower_bound) & (df["rental30"] <= upper_bound)]

#  Cap extreme values (Winsorization) on remaining data
df["rental30"] = winsorize(df["rental30"], limits=[0.01, 0.01])  # Cap at 1% from each side

df = df.reset_index(drop=True)
print(df.shape)
# Out:
# (191401, 34)

# %%
from scipy.stats.mstats import winsorize

#  Filter rows within 2nd and 98th percentiles
lower_bound = df["cnt_da_rech90"].quantile(0.02)
upper_bound = df["cnt_da_rech90"].quantile(0.98)
df = df[(df["cnt_da_rech90"] >= lower_bound) & (df["cnt_da_rech90"] <= upper_bound)]

#  Cap extreme values (Winsorization) on remaining data
df["cnt_da_rech90"] = winsorize(df["cnt_da_rech90"], limits=[0.01, 0.01])  # Cap at 1% from each side

df = df.reset_index(drop=True)
print(df.shape)
# Out:
# (189626, 34)

# %%
from scipy.stats.mstats import winsorize

# Step 1: Filter rows within 2nd and 98th percentiles
lower_bound = df["rental90"].quantile(0.02)
upper_bound = df["rental90"].quantile(0.98)
df = df[(df["rental90"] >= lower_bound) & (df["rental30"] <= upper_bound)]

# Step 2: Cap extreme values (Winsorization) on remaining data
df["rental90"] = winsorize(df["rental90"], limits=[0.01, 0.01])  # Cap at 1% from each side

df = df.reset_index(drop=True)
print(df.shape)
# Out:
# (188000, 34)

# %%
from scipy.stats.mstats import winsorize

# Step 1: Filter rows within 2nd and 98th percentiles
lower_bound = df["cnt_da_rech30"].quantile(0.02)
upper_bound = df["cnt_da_rech30"].quantile(0.98)
df = df[(df["cnt_da_rech30"] >= lower_bound) & (df["cnt_da_rech30"] <= upper_bound)]

# Step 2: Cap extreme values (Winsorization) on remaining data
df["cnt_da_rech30"] = winsorize(df["cnt_da_rech30"], limits=[0.01, 0.01])  # Cap at 1% from each side

df = df.reset_index(drop=True)
print(df.shape)
# Out:
# (187042, 34)

# %%
from scipy.stats.mstats import winsorize

# Step 1: Filter rows within 2nd and 98th percentiles
lower_bound = df["maxamnt_loans30"].quantile(0.02)
upper_bound = df["maxamnt_loans30"].quantile(0.98)
df = df[(df["maxamnt_loans30"] >= lower_bound) & (df["maxamnt_loans30"] <= upper_bound)]

# Step 2: Cap extreme values (Winsorization) on remaining data
df["maxamnt_loans30"] = winsorize(df["maxamnt_loans30"], limits=[0.01, 0.01])  # Cap at 1% from each side

df = df.reset_index(drop=True)
print(df.shape)
# Out:
# (183358, 34)

# %%
from scipy.stats.mstats import winsorize

# Step 1: Filter rows within 2nd and 98th percentiles
lower_bound = df["medianamnt_loans30"].quantile(0.02)
upper_bound = df["medianamnt_loans30"].quantile(0.98)
df = df[(df["medianamnt_loans30"] >= lower_bound) & (df["medianamnt_loans30"] <= upper_bound)]

# Step 2: Cap extreme values (Winsorization) on remaining data
df["medianamnt_loans30"] = winsorize(df["medianamnt_loans30"], limits=[0.01, 0.01])  # Cap at 1% from each side

df = df.reset_index(drop=True)
print(df.shape)
# Out:
# (182935, 34)

# %%
from scipy.stats.mstats import winsorize

# Step 1: Filter rows within 2nd and 98th percentiles
lower_bound = df["amnt_loans90"].quantile(0.02)
upper_bound = df["amnt_loans90"].quantile(0.98)
df = df[(df["amnt_loans90"] >= lower_bound) & (df["amnt_loans90"] <= upper_bound)]

# Step 2: Cap extreme values (Winsorization) on remaining data
df["amnt_loans90"] = winsorize(df["amnt_loans90"], limits=[0.01, 0.01])  # Cap at 1% from each side

df = df.reset_index(drop=True)
print(df.shape)
# Out:
# (179363, 34)

# %%
from scipy.stats.mstats import winsorize

# Step 1: Filter rows within 2nd and 98th percentiles
lower_bound = df["amnt_loans30"].quantile(0.02)
upper_bound = df["amnt_loans30"].quantile(0.98)
df = df[(df["amnt_loans30"] >= lower_bound) & (df["amnt_loans30"] <= upper_bound)]

# Step 2: Cap extreme values (Winsorization) on remaining data
df["amnt_loans30"] = winsorize(df["amnt_loans30"], limits=[0.01, 0.01])  # Cap at 1% from each side

df = df.reset_index(drop=True)
print(df.shape)
# Out:
# (176855, 34)

# %%
df.columns
# Out:
# Index(['label', 'msisdn', 'aon', 'daily_decr30', 'daily_decr90', 'rental30',
#        'rental90', 'last_rech_date_ma', 'last_rech_date_da',
#        'last_rech_amt_ma', 'cnt_ma_rech30', 'fr_ma_rech30',
#        'sumamnt_ma_rech30', 'medianamnt_ma_rech30', 'medianmarechprebal30',
#        'cnt_ma_rech90', 'fr_ma_rech90', 'sumamnt_ma_rech90',
#        'medianamnt_ma_rech90', 'medianmarechprebal90', 'cnt_da_rech30',
#        'fr_da_rech30', 'cnt_da_rech90', 'fr_da_rech90', 'cnt_loans30',
#        'amnt_loans30', 'maxamnt_loans30', 'medianamnt_loans30', 'cnt_loans90',
#        'amnt_loans90', 'maxamnt_loans90', 'medianamnt_loans90', 'payback30',
#        'payback90'],
#       dtype='object')

# %%
df.head()
# Out:
#    label   msisdn    aon  daily_decr30  daily_decr90   rental30   rental90  \
# 0      0  21408.0  272.0      8.055178      8.058379  10.084111  10.125939
# 1      1  76462.0  712.0      9.410585      9.410810  10.219407  10.254632
# 2      1  17943.0  535.0      7.308551      7.308551  10.112097  10.151234
# 3      1  55773.0  241.0      4.755663      4.755663  10.081573  10.121900
# 4      1   3813.0  947.0      5.503834      5.503834  10.120132  10.158962
#
#    last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  \
# 0           3.496508           3.433987          7.340187       1.386294
# 1           3.931826           3.433987          8.663715       1.098612
# 2           3.526361           3.433987          7.340187       1.098612
# 3           4.219508           3.433987          6.855409       0.693147
# 4           3.555348           3.433987          7.745436       2.197225
#
#    fr_ma_rech30  sumamnt_ma_rech30  medianamnt_ma_rech30  \
# 0      3.135494           8.032685                1539.0
# 1      0.693147           8.663715                5787.0
# 2      0.693147           7.340187                1539.0
# 3      0.693147           0.693147                   0.0
# 4      1.386294           9.905036                2309.0
#
#    medianmarechprebal30  cnt_ma_rech90  fr_ma_rech90  sumamnt_ma_rech90  \
# 0                  7.50       1.386294            21           8.032685
# 1                 61.04       1.098612             0           8.663715
# 2                 66.32       1.098612             0           7.340187
# 3                  0.00       1.098612             0           6.855409
# 4                 29.00       2.302585             2          10.064671
#
#    medianamnt_ma_rech90  medianmarechprebal90  cnt_da_rech30  fr_da_rech30  \
# 0                1539.0                  7.50       0.693147      0.526589
# 1                5787.0                 61.04       0.693147      0.526589
# 2                1539.0                 66.32       0.693147      0.526589
# 3                 947.0                  2.50       0.693147      0.526589
# 4                2888.0                 35.00       0.693147      0.526589
#
#    cnt_da_rech90  fr_da_rech90  cnt_loans30  amnt_loans30  maxamnt_loans30  \
# 0       0.526589             0     1.386294      2.639057         2.079442
# 1       0.526589             0     1.098612      2.639057         2.639057
# 2       0.526589             0     1.098612      2.079442         2.079442
# 3       0.526589             0     1.386294      2.639057         2.079442
# 4       0.526589             0     2.197225      3.784190         2.079442
#
#    medianamnt_loans30  cnt_loans90  amnt_loans90  maxamnt_loans90  \
# 0                 0.0     1.386294      2.639057         2.079442
# 1                 0.0     1.098612      2.639057         2.639057
# 2                 0.0     1.098612      2.079442         2.079442
# 3                 0.0     1.386294      2.639057         2.079442
# 4                 0.0     2.197225      3.784190         2.079442
#
#    medianamnt_loans90  payback30  payback90
# 0                 0.0   3.433987   3.433987
# 1                 0.0   0.693147   0.693147
# 2                 0.0   0.693147   0.693147
# 3                 0.0   0.693147   0.693147
# 4                 0.0   1.466337   1.466337

# %%
plt.figure(figsize=(20,20))
graph=1
for num in df[:34]:
    plt.subplot(6,6,graph)
    sns.boxplot(data=df[num],orient="v")
    plt.xlabel(num,fontsize=12)
    graph+=1
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 176855 entries, 0 to 176854
# Data columns (total 34 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   label                 176855 non-null  int64
#  1   msisdn                176855 non-null  float64
#  2   aon                   176855 non-null  float64
#  3   daily_decr30          176855 non-null  float64
#  4   daily_decr90          176855 non-null  float64
#  5   rental30              176855 non-null  float64
#  6   rental90              176855 non-null  float64
#  7   last_rech_date_ma     176855 non-null  float64
#  8   last_rech_date_da     176855 non-null  float64
#  9   last_rech_amt_ma      176855 non-null  float64
#  10  cnt_ma_rech30         176855 non-null  float64
#  11  fr_ma_rech30          176855 non-null  float64
#  12  sumamnt_ma_rech30     176855 non-null  float64
#  13  medianamnt_ma_rech30  176855 non-null  float64
#  14  medianmarechprebal30  176855 non-null  float64
#  15  cnt_ma_rech90         176855 non-null  float64
#  16  fr_ma_rech90          176855 non-null  int64
#  17  sumamnt_ma_rech90     176855 non-null  float64
#  18  medianamnt_ma_rech90  176855 non-null  float64
#  19  medianmarechprebal90  176855 non-null  float64
#  20  cnt_da_rech30         176855 non-null  float64
#  21  fr_da_rech30          176855 non-null  float64
#  22  cnt_da_rech90         176855 non-null  float64
#  23  fr_da_rech90          176855 non-null  int64
#  24  cnt_loans30           176855 non-null  float64
#  25  amnt_loans30          176855 non-null  float64
#  26  maxamnt_loans30       176855 non-null  float64
#  27  medianamnt_loans30    176855 non-null  float64
#  28  cnt_loans90           176855 non-null  float64
#  29  amnt_loans90          176855 non-null  float64
#  30  maxamnt_loans90       176855 non-null  float64
#  31  medianamnt_loans90    176855 non-null  float64
#  32  payback30             176855 non-null  float64
#  33  payback90             176855 non-null  float64
# dtypes: float64(31), int64(3)
# memory usage: 45.9 MB

# %%
#sns.pairplot(df)

# %%
# print the histplot
#plt.figure(figsize=(20,20))
#graph=1
#for num in df[:34]:
#    plt.subplot(6,5,graph)
 #   sns.histplot(data=df[num],kde=True)
  #  plt.xlabel(num,fontsize=12)
   # graph+=1
#plt.show()

# %% [markdown]
# # DATA PREPROCESSING

# %%
# dependent feature in X
X=df.drop(columns=["label"],axis=1)

#  targget feature in y
y=df["label"] #  targget feature in y

# %%
x=X

# %%
x.shape
# Out:
# (176855, 33)

# %% [markdown]
# # STANDIZATION AND NORMALIZATION

# %%
# IMPORT LIBERARYY of minmaxscaler , PowerTransform
from sklearn.preprocessing import MinMaxScaler , PowerTransformer
# powertransform of X data
ptf=PowerTransformer(method='yeo-johnson') # minimize the skeness of data

# %%
# fit_transfform x data
x_ptf=ptf.fit_transform(X)

# %%
# create a dataframe
x=pd.DataFrame(x_ptf,columns=x.columns)
x.head()
# Out:
#      msisdn       aon  daily_decr30  daily_decr90      rental30      rental90  \
# 0 -0.924665 -0.169705      0.609878      0.590924 -3.330669e-16 -9.714451e-17
# 1  0.910532  0.039744      1.190094      1.153178  2.775558e-16  5.551115e-17
# 2 -1.073424 -0.030065      0.259803      0.247252 -1.942890e-16 -5.551115e-17
# 3  0.294668 -0.191342     -1.168760     -1.167610 -3.469447e-16 -9.714451e-17
# 4 -1.823415  0.116804     -0.704613     -0.704616 -1.526557e-16 -5.551115e-17
#
#    last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  \
# 0      -2.567391e-16      -1.776357e-15          0.195148      -0.291680
# 1       9.298118e-16      -1.776357e-15          1.471515      -0.845043
# 2      -7.632783e-17      -1.776357e-15          0.195148      -0.845043
# 3       1.068590e-15      -1.776357e-15         -0.189422      -1.696676
# 4       7.632783e-17      -1.776357e-15          0.549740       1.103884
#
#    fr_ma_rech30  sumamnt_ma_rech30  medianamnt_ma_rech30  \
# 0      1.550582          -0.058036              0.222188
# 1     -1.141558           0.339354              1.730766
# 2     -1.141558          -0.446424              0.222188
# 3     -1.141558          -2.119059             -1.996089
# 4      0.169223           1.248568              0.608156
#
#    medianmarechprebal30  cnt_ma_rech90  fr_ma_rech90  sumamnt_ma_rech90  \
# 0             -0.038384      -0.587130      1.318378          -0.300207
# 1              0.018693      -1.044850     -1.206593           0.066606
# 2              0.022464      -1.044850     -1.206593          -0.658149
# 3             -0.060512      -1.044850     -1.206593          -0.882081
# 4             -0.008883       0.747377     -0.084886           1.027705
#
#    medianamnt_ma_rech90  medianmarechprebal90  cnt_da_rech30  fr_da_rech30  \
# 0              0.198528             -0.353778            0.0 -3.469447e-18
# 1              1.785460              0.004483            0.0 -3.469447e-18
# 2              0.198528              0.034343            0.0 -3.469447e-18
# 3             -0.210783             -0.402148            0.0 -3.469447e-18
# 4              0.854414             -0.152640            0.0 -3.469447e-18
#
#    cnt_da_rech90  fr_da_rech90  cnt_loans30  amnt_loans30  maxamnt_loans30  \
# 0  -3.330669e-16           0.0     0.100594      0.044991    -6.938894e-18
# 1  -3.330669e-16           0.0    -1.080265      0.044991     6.245005e-17
# 2  -3.330669e-16           0.0    -1.080265     -1.149201    -6.938894e-18
# 3  -3.330669e-16           0.0     0.100594      0.044991    -6.938894e-18
# 4  -3.330669e-16           0.0     1.643518      1.552589    -6.938894e-18
#
#    medianamnt_loans30  cnt_loans90  amnt_loans90  maxamnt_loans90  \
# 0           -0.269316    -0.147222     -0.166948    -9.020562e-17
# 1           -0.269316    -1.149675     -0.166948     7.008283e-16
# 2           -0.269316    -1.149675     -1.208067    -9.020562e-17
# 3           -0.269316    -0.147222     -0.166948    -9.020562e-17
# 4           -0.269316     1.289439      1.247009    -9.020562e-17
#
#    medianamnt_loans90  payback30  payback90
# 0           -0.247305   1.747332   1.726497
# 1           -0.247305  -0.938961  -1.019669
# 2           -0.247305  -0.938961  -1.019669
# 3           -0.247305  -0.938961  -1.019669
# 4           -0.247305   0.627146   0.422137

# %%
# Scale the features use of minmaxscaler
import pandas as pd
import numpy as np
originals_colummns=x.columns
scaler = MinMaxScaler()
x_scale = scaler.fit_transform(x)
x=pd.DataFrame(x_scale,columns=x.columns)

# %%
x.head()
# Out:
#      msisdn       aon  daily_decr30  daily_decr90      rental30      rental90  \
# 0  0.340804  0.525928      0.609762      0.605554  4.163336e-17  0.000000e+00
# 1  0.829225  0.537139      0.762409      0.753559  6.522560e-16  1.526557e-16
# 2  0.301213  0.533403      0.517661      0.515088  1.804112e-16  4.163336e-17
# 3  0.665318  0.524770      0.141825      0.142648  2.775558e-17  0.000000e+00
# 4  0.101610  0.541264      0.263936      0.264523  2.220446e-16  4.163336e-17
#
#    last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  \
# 0       4.649059e-16                0.0          0.361330       0.243698
# 1       1.651457e-15                0.0          0.550586       0.147717
# 2       6.453171e-16                0.0          0.361330       0.147717
# 3       1.790235e-15                0.0          0.304307       0.000000
# 4       7.979728e-16                0.0          0.413908       0.485761
#
#    fr_ma_rech30  sumamnt_ma_rech30  medianamnt_ma_rech30  \
# 0      0.656320           0.387492              0.251865
# 1      0.000000           0.462205              0.423150
# 2      0.000000           0.314472              0.251865
# 3      0.000000           0.000000              0.000000
# 4      0.319557           0.633146              0.295688
#
#    medianmarechprebal30  cnt_ma_rech90  fr_ma_rech90  sumamnt_ma_rech90  \
# 0              0.496723       0.216335      0.796063           0.346029
# 1              0.499271       0.129913      0.000000           0.413319
# 2              0.499439       0.129913      0.000000           0.280366
# 3              0.495734       0.129913      0.000000           0.239286
# 4              0.498040       0.468306      0.353647           0.589629
#
#    medianamnt_ma_rech90  medianmarechprebal90  cnt_da_rech30  fr_da_rech30  \
# 0              0.246464              0.128877            0.0           0.0
# 1              0.417320              0.134869            0.0           0.0
# 2              0.246464              0.135369            0.0           0.0
# 3              0.202396              0.128068            0.0           0.0
# 4              0.317080              0.132241            0.0           0.0
#
#    cnt_da_rech90  fr_da_rech90  cnt_loans30  amnt_loans30  maxamnt_loans30  \
# 0            0.0           0.0     0.395239      0.408376     0.000000e+00
# 1            0.0           0.0     0.000000      0.408376     6.938894e-17
# 2            0.0           0.0     0.000000      0.000000     0.000000e+00
# 3            0.0           0.0     0.395239      0.408376     0.000000e+00
# 4            0.0           0.0     0.911663      0.923928     0.000000e+00
#
#    medianamnt_loans30  cnt_loans90  amnt_loans90  maxamnt_loans90  \
# 0                 0.0     0.261395      0.338727     0.000000e+00
# 1                 0.0     0.000000      0.338727     7.910339e-16
# 2                 0.0     0.000000      0.000000     0.000000e+00
# 3                 0.0     0.261395      0.338727     0.000000e+00
# 4                 0.0     0.636012      0.798756     0.000000e+00
#
#    medianamnt_loans90  payback30  payback90
# 0                 0.0   0.904233   0.866033
# 1                 0.0   0.000000   0.000000
# 2                 0.0   0.000000   0.000000
# 3                 0.0   0.000000   0.000000
# 4                 0.0   0.527167   0.454689

# %% [markdown]
# #  apply with PCA and consider some importent feature

# %%
from sklearn.decomposition import PCA

# Initialize PCA and fit to the data
pca = PCA(n_components=14)  # use of 14 importent feature
x_pca = pca.fit_transform(x)

x = pd.DataFrame(x_pca)
x.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.508435  0.154451  0.070245  0.523028 -0.051754  0.696115 -0.073502
# 1 -0.444021  0.275651 -0.413825 -0.561221  0.226549 -0.105483 -0.152397
# 2 -0.905209  0.075236 -0.279317 -0.314471 -0.247594  0.161284 -0.155891
# 3 -0.636659 -0.569412 -0.000619 -0.151908  0.002340 -0.247751  0.246621
# 4  0.864280 -0.389318  0.089250  0.080712 -0.603194 -0.334520 -0.080545
#
#          7         8         9         10        11        12        13
# 0  0.082955 -0.131182  0.137308  0.065534 -0.002064  0.027055  0.005074
# 1 -0.176208 -0.366142  0.102918  0.057687 -0.032836 -0.234744  0.097031
# 2 -0.037441 -0.108386  0.079175  0.007728 -0.005184  0.057256  0.020483
# 3 -0.121652 -0.183933 -0.084226 -0.042584  0.008013 -0.041643 -0.246956
# 4 -0.061040 -0.049474 -0.033045  0.010778  0.000228  0.006249  0.016840

# %%
# checck the shape of dataset after use PCA
x.shape
# Out:
# (176855, 14)

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 176855 entries, 0 to 176854
# Data columns (total 14 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   0       176855 non-null  float64
#  1   1       176855 non-null  float64
#  2   2       176855 non-null  float64
#  3   3       176855 non-null  float64
#  4   4       176855 non-null  float64
#  5   5       176855 non-null  float64
#  6   6       176855 non-null  float64
#  7   7       176855 non-null  float64
#  8   8       176855 non-null  float64
#  9   9       176855 non-null  float64
#  10  10      176855 non-null  float64
#  11  11      176855 non-null  float64
#  12  12      176855 non-null  float64
#  13  13      176855 non-null  float64
# dtypes: float64(14)
# memory usage: 18.9 MB

# %% [markdown]
# # CHECK RANDOM STATE FOR TRAIN_TEST_SPLIT

# %%
# check the random state for train_test_split

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

# use of logisticregresssionn
lr = LogisticRegression()


for i in range(0, 150):
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=i)
    lr.fit(x_train, y_train)

    pred_train = lr.predict(x_train)
    pred_test = lr.predict(x_test)

    train_r2 = accuracy_score(y_train, pred_train) * 100
    test_r2 = accuracy_score(y_test, pred_test) * 100

    # checck condition train and test data
    if round(train_r2, 1) == round(test_r2, 1):
        print("Random state:", i)
        print("Training accuracy_score:", train_r2)
        print("Testing accuracy_score:", test_r2)
# Out:
# Random state: 2
# Training accuracy_score: 86.47974329252777
# Testing accuracy_score: 86.5200305334879
# Random state: 3
# Training accuracy_score: 86.40128919171073
# Testing accuracy_score: 86.35040004523479
# Random state: 6
# Training accuracy_score: 86.69814254615363
# Testing accuracy_score: 86.68400667213254
# Random state: 7
# Training accuracy_score: 86.71581238867999
# Testing accuracy_score: 86.6924881965452
# Random state: 8
# Training accuracy_score: 86.71227842017471
# Testing accuracy_score: 86.70379689576207
# Random state: 16
# Training accuracy_score: 86.70733086426733
# Testing accuracy_score: 86.73206864380425
# Random state: 23
# Training accuracy_score: 86.71298521387577
# Testing accuracy_score: 86.70096972095784
# Random state: 41
# Training accuracy_score: 86.40835712872126
# Testing accuracy_score: 86.38998049249386
# Random state: 50
# Training accuracy_score: 86.69743575245258
# Testing accuracy_score: 86.74620451782533
# Random state: 57
# Training accuracy_score: 86.73065505640214
# Testing accuracy_score: 86.65008057448192
# Random state: 59
# Training accuracy_score: 86.69743575245258
# Testing accuracy_score: 86.71793276978316
# Random state: 66
# Training accuracy_score: 86.48822481694043
# Testing accuracy_score: 86.51720335868367
# Random state: 74
# Training accuracy_score: 86.42814735235079
# Testing accuracy_score: 86.44086963896977
# Random state: 84
# Training accuracy_score: 86.41966582793815
# Testing accuracy_score: 86.38149896808119
# Random state: 85
# Training accuracy_score: 86.71298521387577
# Testing accuracy_score: 86.67552514771988
# Random state: 87
# Training accuracy_score: 86.43804246416555
# Testing accuracy_score: 86.37867179327698
# Random state: 95
# Training accuracy_score: 86.50236069096152
# Testing accuracy_score: 86.51720335868367
# Random state: 97
# Training accuracy_score: 86.49882672245624
# Testing accuracy_score: 86.48893161064149
# Random state: 108
# Training accuracy_score: 86.09666110655621
# Testing accuracy_score: 86.08181843883406
# Random state: 113
# Training accuracy_score: 86.39775522320545
# Testing accuracy_score: 86.36453591925589
# Random state: 115
# Training accuracy_score: 86.35464080744111
# Testing accuracy_score: 86.36453591925589
# Random state: 122
# Training accuracy_score: 86.7172259760821
# Testing accuracy_score: 86.6783523225241
# Random state: 132
# Training accuracy_score: 86.38008538067908
# Testing accuracy_score: 86.39280766729807
# Random state: 137
# Training accuracy_score: 86.72075994458737
# Testing accuracy_score: 86.6613892736988
# Random state: 138
# Training accuracy_score: 86.45429871928981
# Testing accuracy_score: 86.45500551299087
# Random state: 140
# Training accuracy_score: 86.47267535551724
# Testing accuracy_score: 86.54547510672585
# Random state: 141
# Training accuracy_score: 86.71298521387577
# Testing accuracy_score: 86.68400667213254
# Random state: 147
# Training accuracy_score: 86.69884933985468
# Testing accuracy_score: 86.74903169262956
# Random state: 149
# Training accuracy_score: 86.50942862797206
# Testing accuracy_score: 86.51154900907522

# %% [markdown]
# random state = 86

# %%
# split data of train and test
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=84)

# check the shaape of train and test data
print("shape of x_train",x_train.shape)
print("shape of x_test",x_test.shape)
print("shape of y_train",y_train.shape)
print("shape of y_test",y_test.shape)
# Out:
# shape of x_train (141484, 14)
# shape of x_test (35371, 14)
# shape of y_train (141484,)
# shape of y_test (35371,)

# %% [markdown]
# # CHECK THE ENBALANCING DATASET

# %%
from imblearn.over_sampling import SMOTE
from collections import Counter

# %%
# check count calue of y_train
print(y_train.value_counts())
# Out:
# label
# 1    122736
# 0     18748
# Name: count, dtype: int64

# %%
Counter(y_train)
# Out:
# Counter({1: 122736, 0: 18748})

# %%
from imblearn.over_sampling import SMOTE
from collections import Counter

# Define the SMOTE instance with a sampling strategy of 0.8
R_SMP = SMOTE(sampling_strategy=0.80)

# Apply SMOTE to the training data
x_train_ns, y_train_ns = R_SMP.fit_resample(x_train, y_train)

# Print the class distribution before and after SMOTE
print("Before resampling, class distribution:", Counter(y_train))
print("After resampling, class distribution:", Counter(y_train_ns))
# Out:
# Before resampling, class distribution: Counter({1: 122736, 0: 18748})
# After resampling, class distribution: Counter({1: 122736, 0: 98188})

# %% [markdown]
# # Trained the model

# %% [markdown]
# # LOGISTICREGRESSION

# %%
# firstt use of logistic regression alggorithom
from sklearn.metrics import accuracy_score , confusion_matrix
from sklearn.metrics import classification_report
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()

# fit x_train and y_train
lr.fit(x_train_ns,y_train_ns)
# predict the x_test
pred_lr=lr.predict(x_test)

#CHECCK THE ACCURACy amd confussion matrix or classification report OF GBC
print("check the accuracy of model\n",accuracy_score(y_test,pred_lr))
print("confussion metrix\n",confusion_matrix(y_test,pred_lr))
print("classification report\n",classification_report(y_test,pred_lr))
# Out:
# check the accuracy of model
#  0.7861807695569817
# confussion metrix
#  [[ 3272  1402]
#  [ 6161 24536]]
# classification report
#                precision    recall  f1-score   support
#
#            0       0.35      0.70      0.46      4674
#            1       0.95      0.80      0.87     30697
#
#     accuracy                           0.79     35371
#    macro avg       0.65      0.75      0.67     35371
# weighted avg       0.87      0.79      0.81     35371

# %% [markdown]
# # SVC

# %% [raw]
# ##support vector classifire
# #from sklearn.svm import SVC
# #svc=SVC()
#
# # fit x_train and y_train
# #svc.fit(x_train_ns,y_train_ns)
#
# # predict the x_test
# #pred_svc=svc.predict(x_test)
#
# #CHECCK THE ACCURACy amd confussion matrix or classification report OF GBC
# #print("check the accuracy of model\n",accuracy_score(y_test,pred_svc))
# #print("confussion metrix\n",confusion_matrix(y_test,pred_svc))
# #print("classification report\n",classification_report(y_test,pred_svc))

# %% [markdown]
# # GradientBoostingClassifier CLASSIFIER

# %%
# use of gradiant boosting algorithom
#  It combines multiple weak learners (typically decision trees) in a sequential manner
from sklearn.ensemble import GradientBoostingClassifier
gbc=GradientBoostingClassifier()

# fit the gbc model
gbc.fit(x_train_ns,y_train_ns)

# PREDICCT THE X TEST
pred_gbc=gbc.predict(x_test)


#CHECCK THE ACCURACy amd confussion matrix or classification report OF GBC
print("accuracy of gbc",accuracy_score(y_test,pred_gbc))
# CONFUSIONN MATRIX
print("accuracy of gbc",confusion_matrix(y_test,pred_gbc))
# CLASSSIFICCATION REPORT
print("accuracy of gbc",classification_report(y_test,pred_gbc))
# Out:
# accuracy of gbc 0.8187767998194538
# accuracy of gbc [[ 3231  1489]
#  [ 4935 25793]]
# accuracy of gbc               precision    recall  f1-score   support
#
#            0       0.40      0.68      0.50      4720
#            1       0.95      0.84      0.89     30728
#
#     accuracy                           0.82     35448
#    macro avg       0.67      0.76      0.70     35448
# weighted avg       0.87      0.82      0.84     35448

# %% [markdown]
# # Random Rorest classification

# %%
#  It constructs a multitude of decision trees during training and outputs the mode
#  because they reduce overfitting and improve accuracy.
from sklearn.ensemble import RandomForestClassifier
RF=RandomForestClassifier()

# fit the gbc model
RF.fit(x_train_ns,y_train_ns)

# PREDICCT THE X TEST
pred_RF=RF.predict(x_test)

#CHECCK THE ACCURACy amd confussion matrix or classification report OF GBC
print("accuracy of gbc",accuracy_score(y_test,pred_RF))

# CONFUSIONN MATRIX
print("accuracy of gbc",confusion_matrix(y_test,pred_RF))

# CLASSSIFICCATION REPORT
print("accuracy of gbc",classification_report(y_test,pred_RF))
# Out:
# accuracy of gbc 0.8664804784473031
# accuracy of gbc [[ 2725  1995]
#  [ 2738 27990]]
# accuracy of gbc               precision    recall  f1-score   support
#
#            0       0.50      0.58      0.54      4720
#            1       0.93      0.91      0.92     30728
#
#     accuracy                           0.87     35448
#    macro avg       0.72      0.74      0.73     35448
# weighted avg       0.88      0.87      0.87     35448

# %% [markdown]
# # DECISSION TREE CLASSIFIER

# %%
# Decission tree
# decission  splits the data into subsets based on feature values, creating a "tree" structure
from sklearn.tree import DecisionTreeClassifier
DT=DecisionTreeClassifier()

#fit the model
DT.fit(x_train_ns,y_train_ns)
pre=DT.predict(x_test)

#CHECCK THE ACCURACy amd confussion matrix or classification report OF GBC
print("accuracy of model\n",accuracy_score(y_test,pre))
print("confussion metrix\n",confusion_matrix(y_test,pre))
print("classification report\n",classification_report(y_test,pre))
# Out:
# accuracy of model
#  0.8087903407808621
# confussion metrix
#  [[ 2667  2053]
#  [ 4725 26003]]
# classification report
#                precision    recall  f1-score   support
#
#            0       0.36      0.57      0.44      4720
#            1       0.93      0.85      0.88     30728
#
#     accuracy                           0.81     35448
#    macro avg       0.64      0.71      0.66     35448
# weighted avg       0.85      0.81      0.83     35448

# %% [markdown]
# # XGBClassifier

# %%
# xgboost classsifier
# XGBClassifier is a highly efficient and powerful implementation of gradient boosting,
from xgboost import XGBClassifier
xgb=XGBClassifier()

# fit the model
xgb.fit(x_train_ns,y_train_ns)
pre_xgb=xgb.predict(x_test)

#CHECCK THE ACCURACy amd confussion matrix or classification report OF GBC
print("accuracy of model\n",accuracy_score(y_test,pre_xgb))
print("confussion metrix\n",confusion_matrix(y_test,pre_xgb))
print("classification report\n",classification_report(y_test,pre_xgb))
# Out:
# accuracy of model
#  0.8374657205054988
# confussion metrix
#  [[ 3285  1389]
#  [ 4360 26337]]
# classification report
#                precision    recall  f1-score   support
#
#            0       0.43      0.70      0.53      4674
#            1       0.95      0.86      0.90     30697
#
#     accuracy                           0.84     35371
#    macro avg       0.69      0.78      0.72     35371
# weighted avg       0.88      0.84      0.85     35371

# %% [markdown]
# #  SGDClassifier

# %%
from sklearn.linear_model import SGDClassifier
sgd=SGDClassifier()
 #fit the gbc model
sgd.fit(x_train_ns,y_train_ns)
# PREDICCT THE X TEST
pred_sgd=sgd.predict(x_test)

#CHECCK THE ACCURACy amd confussion matrix or classification report OF GBC
print("accuracy of gbc",accuracy_score(y_test,pred_sgd))
# CONFUSIONN MATRIX
print("accuracy of gbc",confusion_matrix(y_test,pred_sgd))
# CLASSSIFICCATION REPORT
print("accuracy of gbc",classification_report(y_test,pred_RF))
# Out:
# accuracy of gbc 0.7887045813586098
# accuracy of gbc [[ 3159  1561]
#  [ 5929 24799]]
# accuracy of gbc               precision    recall  f1-score   support
#
#            0       0.50      0.58      0.54      4720
#            1       0.93      0.91      0.92     30728
#
#     accuracy                           0.87     35448
#    macro avg       0.72      0.74      0.73     35448
# weighted avg       0.88      0.87      0.87     35448

# %% [markdown]
# # KNeighborsClassifier

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier()

knn.fit(x_train_ns,y_train_ns)
pred_knn=knn.predict(x_test)

print("accuracy of model\n",accuracy_score(y_test,pred_knn))
print("confussion metrix\n",confusion_matrix(y_test,pred_knn))
print("classification report\n",classification_report(y_test,pred_knn))
# Out:
# accuracy of model
#  0.7898329948092981
# confussion metrix
#  [[ 3038  1682]
#  [ 5768 24960]]
# classification report
#                precision    recall  f1-score   support
#
#            0       0.34      0.64      0.45      4720
#            1       0.94      0.81      0.87     30728
#
#     accuracy                           0.79     35448
#    macro avg       0.64      0.73      0.66     35448
# weighted avg       0.86      0.79      0.81     35448

# %% [markdown]
# # CROSSVALIDATION

# %% [markdown]
# LOGISTIC REGRESSION

# %%
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from xgboost import XGBClassifier
from sklearn.linear_model import SGDClassifier

def evaluate_models(models, x_train_ns, y_train_ns, cv=5):
    scores = {}
    for name, model in models.items():
        scr = cross_val_score(model, x_train_ns, y_train_ns, cv=cv)
        scores[name] = scr.mean()
    return scores

models = {
    'Logistic Regression': LogisticRegression(),
    'Random Forest': RandomForestClassifier(),
    'Gradient Boosting': GradientBoostingClassifier(),
    'SGDClassifier': SGDClassifier(),
    'Decision Tree': DecisionTreeClassifier(),
    'XGBClassifier': XGBClassifier(),
    'KNN': KNeighborsClassifier()
}

results = evaluate_models(models, x_train_ns, y_train_ns)

for model, score in results.items():
    print(f"{model}: {score:.4f}")
# Out:
# Logistic Regression: 0.7543
# Random Forest: 0.8976
# Gradient Boosting: 0.7764
# SGDClassifier: 0.7457
# Decision Tree: 0.8374
# XGBClassifier: 0.8221
# KNN: 0.8677

# %% [markdown]
# # * Apply Hyperparameter Tuninig

# %% [markdown]
# # XGBCLASSIFIER

# %%
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
# Create an XGBoost model
gsv = XGBClassifier()

from sklearn.model_selection import RandomizedSearchCV
# Define the parameter grid
param_grid = {
    'n_estimators': [100, 200],
    'learning_rate': [0.01, 0.1, 0.2],
    'max_depth': [3, 5, 7],
    'min_child_weight': [1, 3, 5],
    'subsample': [0.6, 0.8, 1.0],
    'colsample_bytree': [0.6, 0.8, 1.0]
    #gamma
}


# Set up the random search
random_search = RandomizedSearchCV(estimator=gsv, param_distributions=param_grid,
                                    n_iter=10, scoring='accuracy', cv=3, verbose=1, n_jobs=-1, random_state=42)


# Fit the random search
random_search.fit(x_train_ns, y_train_ns)


# Get the best parameters
best_params = random_search.best_params_
print("Best parameters found: ", best_params)


#  you can evaluate the model on the test set
best_model = random_search.best_estimator_
predictions = best_model.predict(x_test)


print("accuracy_score:/n",accuracy_score(y_test,predictions))
print("confusion_metrics:/n",confusion_matrix(y_test,predictions))
print("classification_report:/n",classification_report(y_test,predictions))
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Best parameters found:  {'subsample': 0.8, 'n_estimators': 200, 'min_child_weight': 3, 'max_depth': 7, 'learning_rate': 0.1, 'colsample_bytree': 0.8}
# accuracy_score:/n 0.8393316558762828
# confusion_metrics:/n [[ 3348  1409]
#  [ 4274 26340]]
# classification_report:/n               precision    recall  f1-score   support
#
#            0       0.44      0.70      0.54      4757
#            1       0.95      0.86      0.90     30614
#
#     accuracy                           0.84     35371
#    macro avg       0.69      0.78      0.72     35371
# weighted avg       0.88      0.84      0.85     35371

# %% [markdown]
# # DecisionTreeClassifier

# %%
# Create an DECISSIONTREECLASSIFIR model
DT=DecisionTreeClassifier()

from sklearn.model_selection import RandomizedSearchCV
# Define the parameter

param_grid = {
    'max_depth': [3, 5, 10, 15, 20],
    'min_samples_split': [2, 5, 10, 20],
    'min_samples_leaf': [1, 2, 5, 10],
    'max_features': ['sqrt', 'log2', None],
    'max_leaf_nodes': [None, 10, 20, 50, 100],
    'criterion': ['gini', 'entropy'],
    'min_impurity_decrease': [0.0, 0.01, 0.05],
}



# Set up the random search
random_search = RandomizedSearchCV(estimator=DT, param_distributions=param_grid,
                                    n_iter=50, scoring='accuracy', cv=5, verbose=1, n_jobs=-1, random_state=42)


# Fit the random search
random_search.fit(x_train_ns, y_train_ns)


# Get the best parameters
best_params_dt = random_search.best_params_
print("Best parameters found: ", best_params_dt)


#  you can evaluate the model on the test set
best_model_dt = random_search.best_estimator_
predictions_dt = best_model_dt.predict(x_test)


print("accuracy_score:/n",accuracy_score(y_test,predictions_dt))
print("confusion_metrics:/n",confusion_matrix(y_test,predictions_dt))
print("classification_report:/n",classification_report(y_test,predictions_dt))
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Best parameters found:  {'min_samples_split': 20, 'min_samples_leaf': 10, 'min_impurity_decrease': 0.0, 'max_leaf_nodes': None, 'max_features': None, 'max_depth': 20, 'criterion': 'entropy'}
# accuracy_score:/n 0.7966598961859626
# confusion_metrics:/n [[ 3075  1645]
#  [ 5563 25165]]
# classification_report:/n               precision    recall  f1-score   support
#
#            0       0.36      0.65      0.46      4720
#            1       0.94      0.82      0.87     30728
#
#     accuracy                           0.80     35448
#    macro avg       0.65      0.74      0.67     35448
# weighted avg       0.86      0.80      0.82     35448

# %% [markdown]
# # GradientBoostingClassifier

# %%
#Create an GRADIANTBOOSTING CLASSIFIER model
GBC=GradientBoostingClassifier()

from sklearn.model_selection import RandomizedSearchCV
 #Define the parameter grid

param_grid = {
   'n_estimators': [100, 200],
   'learning_rate': [0.01, 0.1],
   'max_depth': [3, 4],
   'min_samples_split': [2, 5],
   'min_samples_leaf': [1, 2],
   'max_features': ['sqrt', None],
   'subsample': [0.8, 1.0],
}



# Set up the random search
random_search_gbc = RandomizedSearchCV(estimator=GBC, param_distributions=param_grid,
                                    n_iter=10, scoring='accuracy', cv=3, verbose=1, n_jobs=-1, random_state=42)


# Fit the random search
random_search_gbc.fit(x_train_ns, y_train_ns)


# Get the best parameters
best_params_gbc = random_search_gbc.best_params_
print("Best parameters found: ", best_params_gbc)


#  you can evaluate the model on the test set
best_model_gbc = random_search_gbc.best_estimator_
predictions_gbc = best_model_gbc.predict(x_test)


print("accuracy_score:/n",accuracy_score(y_test,predictions_gbc))
print("confusion_metrics:/n",confusion_matrix(y_test,predictions_gbc))
print("classification_report:/n",classification_report(y_test,predictions_gbc))
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Best parameters found:  {'subsample': 0.8, 'n_estimators': 200, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'max_depth': 4, 'learning_rate': 0.1}
# accuracy_score:/n 0.8310482960956894
# confusion_metrics:/n [[ 3284  1436]
#  [ 4553 26175]]
# classification_report:/n               precision    recall  f1-score   support
#
#            0       0.42      0.70      0.52      4720
#            1       0.95      0.85      0.90     30728
#
#     accuracy                           0.83     35448
#    macro avg       0.68      0.77      0.71     35448
# weighted avg       0.88      0.83      0.85     35448

# %% [markdown]
# # RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier
# Create an randomforestclassifuer model
RF=RandomForestClassifier()

from sklearn.model_selection import RandomizedSearchCV
# Define the parameter grid

param_grid = {

    'n_estimators': [100, 200,300,400],  # Reduced number of trees
    'max_depth': [None, 10,20,30],  # Reduced depth options
    'min_samples_split': [2, 5,6,8],  # Reduced min samples to split
    'min_samples_leaf': [1, 2,3,4],  # Reduced min samples at a leaf
    'max_features': ['sqrt'],  # Only one option for max features
    'bootstrap': [True,False],  # Only one option for bootstrapping
}




# Set up the random search
random_search_rf = RandomizedSearchCV(estimator=RF, param_distributions=param_grid,
                                    n_iter=10, scoring='accuracy', cv=5, verbose=1, n_jobs=-1, random_state=42)


# Fit the random search
random_search_rf.fit(x_train_ns, y_train_ns)


# Get the best parameters
best_params_rf = random_search_rf.best_params_
print("Best parameters found: ", )


#  you can evaluate the model on the test set
best_model_rf = random_search_rf.best_estimator_
predictions_rf = best_model_rf.predict(x_test)

best_params_rf
print("accuracy_score:/n",accuracy_score(y_test,predictions_rf))
print("confusion_metrics:/n",confusion_matrix(y_test,predictions_rf))
print("classification_report:/n",classification_report(y_test,predictions_rf))
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Best parameters found:
# accuracy_score:/n 0.8723813293375929
# confusion_metrics:/n [[ 2759  1998]
#  [ 2516 28098]]
# classification_report:/n               precision    recall  f1-score   support
#
#            0       0.52      0.58      0.55      4757
#            1       0.93      0.92      0.93     30614
#
#     accuracy                           0.87     35371
#    macro avg       0.73      0.75      0.74     35371
# weighted avg       0.88      0.87      0.88     35371

# %% [markdown]
# # knearestClassifier

# %%
# Create an kneigoborcclassifier model
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier()

from sklearn.model_selection import RandomizedSearchCV
# Define the parameter grid

param_grid = {

    'n_neighbors': range(5, 30),  # Larger range to prevent overfitting
    'weights': ['uniform', 'distance'],  # Weight closer neighbors more
    'metric': ['euclidean', 'manhattan'],  # Try different distance metrics
}
    #max_features




# Set up the random search
random_search_knn = RandomizedSearchCV(estimator=knn, param_distributions=param_grid,
                                    n_iter=10, scoring='accuracy', cv=5, verbose=1, n_jobs=-1, random_state=42)


# Fit the random search
random_search_knn.fit(x_train_ns, y_train_ns)


# Get the best parameters
best_params_knn = random_search_knn.best_params_
print("Best parameters found: ", best_params_knn)


#  you can evaluate the model on the test set
best_model_knn = random_search_knn.best_estimator_
predictions_rf = best_model_knn.predict(x_test)


print("accuracy_score:/n",accuracy_score(y_test,predictions_rf))
print("confusion_metrics:/n",confusion_matrix(y_test,predictions_rf))
print("classification_report:/n",classification_report(y_test,predictions_rf))
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Best parameters found:  {'weights': 'distance', 'n_neighbors': 6, 'metric': 'manhattan'}
# accuracy_score:/n 0.8044443187922309
# confusion_metrics:/n [[ 3001  1756]
#  [ 5161 25453]]
# classification_report:/n               precision    recall  f1-score   support
#
#            0       0.37      0.63      0.46      4757
#            1       0.94      0.83      0.88     30614
#
#     accuracy                           0.80     35371
#    macro avg       0.65      0.73      0.67     35371
# weighted avg       0.86      0.80      0.82     35371

# %% [markdown]
# # RANDOMFORESTCLASSIFIER IS THE BEST MODEL WITH HYPERPARAMETER TUNING and crossvalidation

# %% [markdown]
# # save the best model

# %%
# using pickle
import pickle

# Save the model to a file
with open("best_model_rf.pkl", "wb") as file:
    pickle.dump(best_model_rf, file)

print("Model saved to best_model_rf_2.pkl")


# Load the model from the file
with open("best_model_rf.pkl", "rb") as file:
    loaded_model_rf = pickle.load(file)

loaded_model_rf.predict(x_test)
# Out:
# Model saved to best_model_rf_2.pkl
# array([1, 1, 1, ..., 1, 1, 1], dtype=int64)
